# %% [markdown]
# # Выборка и агрегация данных в MongoDB
#
# ###Цель домашней работы
#
# Закрепить на практике основные приемы работы с СУБД MongoDB, включая выборку, сортировку, объединение, агрегацию данных и передачу результатов выборки в программу на Python в целях аналитики и дальнейшей обработки.

# %% [markdown]
# ### Формулировка задания
#
# В этом задании вам предстоит выполнить несколько запросов к базе данных для получения выборок по условиям, а также воспользоваться фреймворком агрегации MongoDB для построения конвейера обработки данных.
#
# Максимальное количество баллов за выполнение домашней работы: 10.

# %% [markdown]
# ##Что нужно использовать в работе над заданием
#
# I. MongoDB:
#
# 1. Зарегистрируйтесь в сервисе MongoDB Atlas: https://www.mongodb.com/atlas/database.
# 1. Создайте кластер уровня M0 (это бесплатно).
# 1. Добавьте в кластер тестовую базу данных `sample_mflix`, используя опцию Load Sample Dataset.
#
# В качестве альтернативы вы можете установить MongoDB на свой локальный компьютер и импортировать необходимые датасеты в свою СУБД, загрузив их по ссылке: https://github.com/neelabalan/mongodb-sample-dataset/tree/main/sample_mflix. Для этого подключитесь к своему серверу через Compass, создайте новую БД, создайте для каждого датасета коллекцию и щелкните «Add data» → «Import JSON or CSV file».
#
# II. MongoDB Compass — в качестве вспомогательного инструмента для конструирования запросов и агрегаций.
#
# III. Python и библиотека pymongo. Работа ведется в Jupyter Notebook или Google Colaboratory. Рекомендуется использовать версию Python 3.12.

# %% [markdown]
# ##Ожидаемые результаты
#
# Результаты работы необходимо оформить в виде ноутбука Jupyter. Можно загрузить файл в LMS либо поделиться ссылкой на Google Colaboratory.

# %% [markdown]
# ##Место где нужно выполнить задание

# %%
#Начать выполнение задания тут

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://betsukeli97:Krasivoeshastie97@ilyabetsukeli.wuesmh1.mongodb.net/?retryWrites=true&w=majority&appName=IlyaBetsukeli"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# ### Упражнение 1. Запросы на выборку

# %% [markdown]
# Цель этого упражнения — закрепить навык выполнения запросов на выборку. Все запросы выполняются на базе `sample_mflix` с данными о кинофильмах.

# %% [markdown]
# #### Задача 1.1 — **1 балл**

# %% [markdown]
# Выведите из коллекции `theaters` документы о кинотеатрах в городе Florence, штат KY.
#
# Для справки:
#
# * Обратите внимание на то, что информация об адресе кинотеатров хранится во вложенных документах. Для доступа к полям вложенных документов следует использовать точку: `родительский_документ.вложенный_документ.поле`.
# * В случае затруднений с написанием логического условия обращайтесь к сопоставлению синтаксиса SQL и Mongo: https://www.mongodb.com/docs/manual/reference/sql-comparison/.
# * Если вы предпочитаете сперва выполнять запросы в Compass, из этого приложения можно выгружать код готового запроса на Python (кнопка с символом `</>`).

# %%
# Ваш код здесь
theaters = client.sample_mflix.theaters
list(theaters.find(
    {
    'location.address.state': 'KY', 
    'location.address.city': 'Florence'
    }
))
# Out:
# [{'_id': ObjectId('59a47287cfa9a3a73e51e893'),
#   'theaterId': 161,
#   'location': {'address': {'street1': '100 Meijer Dr.',
#     'city': 'Florence',
#     'state': 'KY',
#     'zipcode': '41042'},
#    'geo': {'type': 'Point', 'coordinates': [-84.636383, 39.014843]}}},
#  {'_id': ObjectId('59a47287cfa9a3a73e51ea02'),
#   'theaterId': 2823,
#   'location': {'address': {'street1': '2823 Florence Mall',
#     'street2': '#2148',
#     'city': 'Florence',
#     'state': 'KY',
#     'zipcode': '41042'},
#    'geo': {'type': 'Point', 'coordinates': [-84.6499595, 38.9967246]}}}]

# %% [markdown]
# #### Задача 1.2 — **1 балл**

# %% [markdown]
# Сделав запрос к коллекции `comments`, выведите _один_ комментарий (значение поля `text`) пользователя по имени Doreah.

# %%
# Ваш код здесь
comments = client.sample_mflix.comments
comments.find({"name" : "Doreah"})[0]["text"]
# Out:
# 'Porro explicabo cumque vitae sint quia quis. Consequuntur voluptatibus optio maxime ratione temporibus incidunt minus architecto.'

# %% [markdown]
# #### Задача 1.3 — **1 балл**

# %% [markdown]
# Сделав запрос к коллекции `movies`, выведите количество документов, в которых в качестве первого жанра фильма (поле `genres`) указано значение «Horror».
#
# Для справки:
#
# 1. Обратите внимание, что поле `genres` представляет собой массив (индексация массивов начинается с нуля).
# 1. При работе в MongoDB Shell для подсчета количества документов в курсоре можно использовать метод `count()`, однако он был удален в последних версиях библиотеки pymongo. В случае затруднений с использованием функций Mongo можно использовать для подсчета документов средства Python.

# %%
# Ваш код здесь
movies = client.sample_mflix.movies
len(list(movies.find({"genres" : "Horror"})))
# Out:
# 1470

# %% [markdown]
# #### Задача 1.4 — **2 балла**

# %% [markdown]
# Выведите из коллекции `movies` документы о фильмах, которые в качестве первого жанра определены как «Film-Noir» либо «Horror» и были выпущены в период с 1940 по 1949 гг. (включительно).

# %%
# Ваш код здесь
movies = client.sample_mflix.movies
list(movies.find({
    '$or': [
        {
            'genres': 'Film-Noir'
        }, {
            'genres': 'Horror'
        }, {
            'year': {
                '$gt': 1939
            }
        }
    ], 
    'year': {
        '$lt': 1950
    }
}
    ))
# Out:
# [{'_id': ObjectId('573a1391f29313caabcd935e'),
#   'plot': "Rico is a small-time hood who knocks off gas stations for whatever he can take. He heads east and signs up with Sam Vettori's mob. A New Year's Eve robbery at Little Arnie Lorch's casino ...",
#   'genres': ['Crime', 'Drama', 'Film-Noir'],
#   'runtime': 79,
#   'cast': ['Edward G. Robinson',
#    'Douglas Fairbanks Jr.',
#    'Glenda Farrell',
#    'William Collier Jr.'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYzE4ZTI3MDQtMTE5MS00MzQxLTkwZGMtYWM5MjU2MzE3OTk5XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Little Caesar',
#   'fullplot': "Rico is a small-time hood who knocks off gas stations for whatever he can take. He heads east and signs up with Sam Vettori's mob. A New Year's Eve robbery at Little Arnie Lorch's casino results in the death of the new crime commissioner Alvin McClure. Rico's good friend Joe Massara, who works at the club as a professional dancer, works as the gang's lookout man and wants out of the gang. Rico is ambitious and eventually takes over Vettori's gang; he then moves up to the next echelon pushing out Diamond Pete Montana. When he orders Joe to dump his girlfriend Olga and re-join the gang, Olga decides there's only one way out for them.",
#   'languages': ['English'],
#   'released': datetime.datetime(1931, 1, 25, 0, 0),
#   'directors': ['Mervyn LeRoy'],
#   'writers': ['W.R. Burnett (novel)',
#    'Robert N. Lee (continuity)',
#    'Francis Edward Faragoh (screen version)',
#    'Francis Edward Faragoh (dialogue)'],
#   'awards': {'wins': 2,
#    'nominations': 0,
#    'text': 'Nominated for 1 Oscar. Another 1 win.'},
#   'lastupdated': '2015-09-05 00:00:20.783000000',
#   'year': 1931,
#   'imdb': {'rating': 7.4, 'votes': 8049, 'id': 21079},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 5963, 'meter': 75},
#    'dvd': datetime.datetime(2005, 1, 25, 0, 0),
#    'critic': {'rating': 7.5, 'numReviews': 20, 'meter': 90},
#    'lastUpdated': datetime.datetime(2015, 9, 2, 19, 37, 5),
#    'rotten': 2,
#    'production': 'Warner Home Video',
#    'fresh': 18}},
#  {'_id': ObjectId('573a1391f29313caabcd9637'),
#   'plot': 'The ancient vampire Count Dracula arrives in England and begins to prey upon the virtuous young Mina.',
#   'genres': ['Horror'],
#   'runtime': 85,
#   'rated': 'APPROVED',
#   'cast': ['Bela Lugosi', 'Helen Chandler', 'David Manners', 'Dwight Frye'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZDY2ODZhZWQtNDk0ZS00OGE4LWE4NjAtZjE5MTJhMjExMTRjXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Dracula',
#   'fullplot': "After a harrowing ride through the Carpathian mountains in eastern Europe, Renfield enters castle Dracula to finalize the transferral of Carfax Abbey in London to Count Dracula, who is in actuality a vampire. Renfield is drugged by the eerily hypnotic count, and turned into one of his thralls, protecting him during his sea voyage to London. After sucking the blood and turning the young Lucy Weston into a vampire, Dracula turns his attention to her friend Mina Seward, daughter of Dr. Seward who then calls in a specialist, Dr. Van Helsing, to diagnose the sudden deterioration of Mina's health. Van Helsing, realizing that Dracula is indeed a vampire, tries to prepare Mina's fiance, John Harker, and Dr. Seward for what is to come and the measures that will have to be taken to prevent Mina from becoming one of the undead.",
#   'languages': ['English', 'Hungarian', 'Latin'],
#   'released': datetime.datetime(1931, 2, 14, 0, 0),
#   'directors': ['Tod Browning'],
#   'writers': ['Bram Stoker (by)',
#    'Hamilton Deane (from the play adapted by)',
#    'John L. Balderston (from the play adapted by)',
#    'Garrett Fort (play)'],
#   'awards': {'wins': 2, 'nominations': 1, 'text': '2 wins & 1 nomination.'},
#   'lastupdated': '2015-08-28 00:30:04.660000000',
#   'year': 1931,
#   'imdb': {'rating': 7.6, 'votes': 30184, 'id': 21814},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 44035, 'meter': 82},
#    'dvd': datetime.datetime(2001, 8, 28, 0, 0),
#    'critic': {'rating': 7.9, 'numReviews': 45, 'meter': 91},
#    'lastUpdated': datetime.datetime(2015, 9, 17, 18, 59, 44),
#    'consensus': "Bela Lugosi's timeless portrayal of Dracula in this creepy and atmospheric 1931 film has set the standard for major vampiric roles since.",
#    'rotten': 4,
#    'production': 'Universal Pictures',
#    'fresh': 41}},
#  {'_id': ObjectId('573a1392f29313caabcd9a3b'),
#   'plot': 'Dr. Jekyll faces horrible consequences when he lets his dark side run wild with a potion that changes him into the animalistic Mr. Hyde.',
#   'genres': ['Horror', 'Sci-Fi'],
#   'runtime': 98,
#   'rated': 'PASSED',
#   'cast': ['Fredric March', 'Miriam Hopkins', 'Rose Hobart', 'Holmes Herbert'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNWRmZWNlNmMtNmVhMi00OThhLWEyNjgtNTY3OTljY2ZlYjBiXkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Dr. Jekyll and Mr. Hyde',
#   'fullplot': 'Based on the story by Robert Louis Stevenson, Dr. Henry Jekyll believes that there are two distinct sides to men - a good and an evil side. He believes that by separating the two man can become liberated. He succeeds in his experiments with chemicals to accomplish this and transforms into Hyde to commit horrendous crimes. When he discontinues use of the drug it is already too late...',
#   'languages': ['English'],
#   'released': datetime.datetime(1932, 1, 3, 0, 0),
#   'directors': ['Rouben Mamoulian'],
#   'writers': ['Samuel Hoffenstein (screen play)',
#    'Percy Heath (screen play)',
#    'Robert Louis Stevenson (based on the novel by)'],
#   'awards': {'wins': 3,
#    'nominations': 2,
#    'text': 'Won 1 Oscar. Another 2 wins & 2 nominations.'},
#   'lastupdated': '2015-08-21 00:15:38.343000000',
#   'year': 1931,
#   'imdb': {'rating': 7.7, 'votes': 8532, 'id': 22835},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 5452, 'meter': 79},
#    'dvd': datetime.datetime(2004, 1, 6, 0, 0),
#    'critic': {'rating': 8.3, 'numReviews': 27, 'meter': 93},
#    'lastUpdated': datetime.datetime(2015, 8, 17, 18, 48, 38),
#    'consensus': 'A classic. The definitive version of the Robert Louis Stevenson novella from 1931, with innovative special effects, atmospheric cinematography and deranged overacting.',
#    'rotten': 2,
#    'production': 'Paramount Pictures',
#    'fresh': 25}},
#  {'_id': ObjectId('573a1392f29313caabcda241'),
#   'plot': 'American honeymooners in Hungary are trapped in the home of a Satan- worshiping priest when the bride is taken there for medical help following a road accident.',
#   'genres': ['Horror', 'Crime', 'Adventure'],
#   'runtime': 65,
#   'cast': ['Boris Karloff', 'Bela Lugosi', 'David Manners', 'Julie Bishop'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNTkzZmMzZDEtNGVlNC00MDdlLThjZDctOTg2YzY2YjMxN2IxXkEyXkFqcGdeQXVyMTE2NzA0Ng@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Black Cat',
#   'fullplot': "Honeymooning in Hungary, Joan and Peter Allison share their train compartment with Dr. Vitus Verdegast, a courtly but tragic man who is returning to the remains of the town he defended before becoming a prisoner of war for fifteen years. When their hotel-bound bus crashes in a mountain storm and Joan is injured, the travellers seek refuge in the home, built fortress-like upon the site of a bloody battlefield, of famed architect Hjalmar Poelzig. There, cat-phobic Verdegast learns his wife's fate, grieves for his lost daughter, and must play a game of chess for Allison's life.",
#   'languages': ['English', 'Latin', 'Hungarian'],
#   'released': datetime.datetime(1934, 5, 7, 0, 0),
#   'directors': ['Edgar G. Ulmer'],
#   'writers': ['Edgar Allan Poe (suggested by a story by)',
#    'Peter Ruric (screenplay)',
#    'Edgar G. Ulmer (story)',
#    'Peter Ruric (story)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-09-15 03:21:38.007000000',
#   'year': 1934,
#   'imdb': {'rating': 7.2, 'votes': 5624, 'id': 24894},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 3430, 'meter': 73},
#    'dvd': datetime.datetime(1992, 9, 10, 0, 0),
#    'critic': {'rating': 7.6, 'numReviews': 30, 'meter': 87},
#    'lastUpdated': datetime.datetime(2015, 9, 11, 18, 18, 41),
#    'consensus': 'Making the most of its Karloff-Lugosi star pairing and loads of creepy atmosphere, The Black Cat is an early classic in the Universal monster movie library.',
#    'rotten': 4,
#    'production': 'Universal',
#    'fresh': 26},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1392f29313caabcda482'),
#   'plot': 'A man and his wife receive a clue to an imminent assassination attempt, only to learn that their daughter has been kidnapped to keep them quiet.',
#   'genres': ['Crime', 'Film-Noir', 'Mystery'],
#   'runtime': 75,
#   'rated': 'APPROVED',
#   'cast': ['Leslie Banks', 'Edna Best', 'Peter Lorre', 'Frank Vosper'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZWY2ODJhOTYtMTE1My00OTBiLTliZTgtNWIwZWIyMWNjODczXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Man Who Knew Too Much',
#   'fullplot': "While holidaying in Switzerland, Lawrence and his wife Jill are asked by a dying friend, Louis Bernard, to get information hidden in his room to the British Consulate. They get the information, but when they deny having it, their daughter Betty is kidnapped. It turns out that Louis was a Foreign Office spy and the information has to do with the assassination of a foreign dignitary. Having managed to trace his daughter's kidnappers back to London, Lawrence learns that the assassination will take place during a concert at the Albert Hall. It is left to Jill, however, to stop the assassination.",
#   'languages': ['English', 'German', 'Italian'],
#   'released': datetime.datetime(1935, 4, 15, 0, 0),
#   'directors': ['Alfred Hitchcock'],
#   'writers': ['Charles Bennett (by)',
#    'D.B. Wyndham-Lewis (by)',
#    'Edwin Greenwood (scenario)',
#    'A.R. Rawlinson (scenario)',
#    'Emlyn Williams (additional dialogue)'],
#   'awards': {'wins': 2, 'nominations': 0, 'text': '2 wins.'},
#   'lastupdated': '2015-08-10 01:02:32.690000000',
#   'year': 1934,
#   'imdb': {'rating': 6.9, 'votes': 11639, 'id': 25452},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 8505, 'meter': 67},
#    'dvd': datetime.datetime(2003, 1, 21, 0, 0),
#    'critic': {'rating': 7.6, 'numReviews': 28, 'meter': 89},
#    'lastUpdated': datetime.datetime(2015, 8, 25, 18, 57, 15),
#    'rotten': 3,
#    'fresh': 25},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1392f29313caabcda826'),
#   'plot': "An American businessman's family convinces him to buy a Scottish castle and disassemble it to ship it to America brick by brick, where it will be put it back together. The castle though is ...",
#   'genres': ['Comedy', 'Fantasy', 'Horror'],
#   'runtime': 95,
#   'rated': 'APPROVED',
#   'cast': ['Robert Donat',
#    'Jean Parker',
#    'Eugene Pallette',
#    'Elsa Lanchester'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMDhiMjE2MzktYzQzNi00MDFmLThiMWUtZTMwYmFhZjIyYzc4XkEyXkFqcGdeQXVyNjE5MjUyOTM@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Ghost Goes West',
#   'fullplot': "An American businessman's family convinces him to buy a Scottish castle and disassemble it to ship it to America brick by brick, where it will be put it back together. The castle though is not the only part of the deal, with it goes the several-hundred year old ghost who haunts it.",
#   'languages': ['English'],
#   'released': datetime.datetime(1936, 2, 7, 0, 0),
#   'directors': ['Renè Clair'],
#   'writers': ['Renè Clair',
#    'Eric Keown (story)',
#    'Geoffrey Kerr (scenario)',
#    'Robert E. Sherwood'],
#   'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'},
#   'lastupdated': '2015-09-02 00:36:23.240000000',
#   'year': 1935,
#   'imdb': {'rating': 6.8, 'votes': 1072, 'id': 26406},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 190, 'meter': 56},
#    'production': 'Criterion Collection',
#    'lastUpdated': datetime.datetime(2015, 8, 31, 18, 17, 48)}},
#  {'_id': ObjectId('573a1392f29313caabcdabdd'),
#   'plot': 'When a hard-working machinist loses a promotion to a Polish-born worker, he is seduced into joining the secretive Black Legion, which intimidates foreigners through violence.',
#   'genres': ['Crime', 'Drama', 'Film-Noir'],
#   'runtime': 83,
#   'rated': 'APPROVED',
#   'cast': ['Humphrey Bogart',
#    'Dick Foran',
#    "Erin O'Brien-Moore",
#    'Ann Sheridan'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZmU5MGQ2M2MtYmRlMy00MDY1LWFiZWQtYTdjOWMxYzdjMWEzXkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Black Legion',
#   'fullplot': 'Frank Taylor joins the "pro-American" Black Legion when he loses his chance at foremanship to a foreign-born man. The organization is a sort of Ku Klux Klan in the industrial sphere. Frank has troubles with his wife over this and causes serious trouble when he tells all to his best friend Ed Jackson.',
#   'languages': ['English'],
#   'released': datetime.datetime(1937, 1, 30, 0, 0),
#   'directors': ['Archie Mayo', 'Michael Curtiz'],
#   'writers': ['Abem Finkel (screen play)',
#    'William Wister Haines (screen play)',
#    'Robert Lord (story)'],
#   'awards': {'wins': 2,
#    'nominations': 0,
#    'text': 'Nominated for 1 Oscar. Another 1 win.'},
#   'lastupdated': '2015-09-17 04:39:07.407000000',
#   'year': 1937,
#   'imdb': {'rating': 7.0, 'votes': 1700, 'id': 27367},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 596, 'meter': 56},
#    'dvd': datetime.datetime(2008, 3, 25, 0, 0),
#    'production': 'WARNER BROTHERS PICTURES',
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 17, 42)}},
#  {'_id': ObjectId('573a1392f29313caabcdad95'),
#   'plot': 'A scientist becomes murderous after discovering, and being exposed to the radiation of, a powerful new element called Radium X.',
#   'genres': ['Horror', 'Sci-Fi', 'Thriller'],
#   'runtime': 80,
#   'rated': 'APPROVED',
#   'cast': ['Boris Karloff', 'Bela Lugosi', 'Frances Drake', 'Frank Lawton'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzMDc4NjE2Nl5BMl5BanBnXkFtZTgwNzIwNTk1MjE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Invisible Ray',
#   'fullplot': "Visionary scientist Janos Rukh convinces a group of scientists and supporters to mount an expedition to the African continent to locate and study an ancient meteorite of great significance. He exposes himself to the highly toxic radiation of the meteorite, and while an antidote devised by Dr. Benet saves him from death by radiation poisoning, his naked touch causes instant death to others. Back in London, the benefits of the meteorite's controlled radiation offer Dr. Benet an opportunity to restore eyesight to the blind. The antidote's toxicity excites Prof. Rukh into paranoid rages as he seeks revenge against the members of his expedition, who he accuses of stealing his discovery for their own glory.",
#   'languages': ['English', 'French'],
#   'released': datetime.datetime(1936, 1, 20, 0, 0),
#   'directors': ['Lambert Hillyer'],
#   'writers': ['John Colton (screenplay)',
#    'Howard Higgin (original story)',
#    'Douglas Hodges (original story)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-08-09 00:51:41.850000000',
#   'year': 1936,
#   'imdb': {'rating': 6.7, 'votes': 1366, 'id': 27800},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 351, 'meter': 49},
#    'critic': {'rating': 6.4, 'numReviews': 5, 'meter': 80},
#    'lastUpdated': datetime.datetime(2015, 8, 12, 19, 6, 27),
#    'rotten': 1,
#    'production': 'MCA Universal Home Video',
#    'fresh': 4},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1392f29313caabcdb314'),
#   'plot': 'A crusading DA persuades a clip joint "party girl" to testify against her mobster boss after her innocent sister is accidentally murdered during one of his unsavory "parties."',
#   'genres': ['Crime', 'Film-Noir', 'Thriller'],
#   'runtime': 96,
#   'rated': 'APPROVED',
#   'cast': ['Bette Davis', 'Humphrey Bogart', 'Lola Lane', 'Isabel Jewell'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNTQ2MTViNWEtODQ5YS00MDViLThiNGMtMjg3YTBjYjRiNTk0L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Marked Woman',
#   'fullplot': 'In this roman-a-clef for the infamous Lucky Luciano Trial, Mary Dwight and four roommates work as hostesses at the Club Intime, a "clip joint" that offers gambling, liquor, and female companionship to the "big spender" clientèle. When ruthless thug and pimp Johnny Vanning takes over all the clubs in town, the girls are forced to follow Vanning\'s rules and kick back on their "tips" in exchange for protection. Although she is not a hardened old hand like Gabby and Estella, Mary knows enough to sidestep Vanning\'s amorous advances. Unfortunately the more naive Mary Lou is impressed by Vanning\'s oily veneer of materialism and accepts invitations to "entertain" at the gangster\'s private parties. Mary\'s naive younger sister Betty arrives from college just when Mary and her roommates are arrested as material witnesses in the murder of one of the casino\'s non-paying customers. Vanning\'s corrupt lawyer frees the others but pressures Mary to commit perjury in order to discredit crusading District Attorney David Graham. Disillusioned by her sister\'s lifestyle. Betty consents to accompany Emmy Lou to one of Vanning\'s private parties where the gangster ends up killing her for not submitting to the advances of one of the party\'s guests. Mary decides to tell the truth to the D.A., and is beaten to disfigurement by one of Vanning\'s hoods. Even so, Mary agrees to testify - and at her bedside, all the other hostesses decide to follow her example in the coming hearing. (original by duke1029)',
#   'languages': ['English'],
#   'released': datetime.datetime(1937, 4, 10, 0, 0),
#   'directors': ['Lloyd Bacon', 'Michael Curtiz'],
#   'writers': ['Robert Rossen (original screen play)',
#    'Abem Finkel (original screen play)'],
#   'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'},
#   'lastupdated': '2015-08-30 00:55:10.257000000',
#   'year': 1937,
#   'imdb': {'rating': 7.4, 'votes': 2251, 'id': 29217},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 621, 'meter': 72},
#    'dvd': datetime.datetime(2006, 5, 30, 0, 0),
#    'production': 'MGM Home Entertainment',
#    'lastUpdated': datetime.datetime(2015, 8, 25, 18, 58, 31)}},
#  {'_id': ObjectId('573a1392f29313caabcdb4d5'),
#   'plot': 'A politically ambitious district attorney, unscrupulous tabloid journalists, and regional prejudice combine to charge a teacher with the murder of his student.',
#   'genres': ['Drama', 'Film-Noir', 'Mystery'],
#   'runtime': 95,
#   'rated': 'APPROVED',
#   'cast': ['Claude Rains', 'Gloria Dickson', 'Edward Norris', 'Otto Kruger'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNTg4ZjM0YjgtMzNiNi00MmZmLThmYzEtY2ZiN2NjOTY4ZmNiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg',
#   'title': "They Won't Forget",
#   'fullplot': "A southern town is rocked by scandal when teenager Mary Clay is murdered on Confederate Decoration Day. Andrew Griffin, a small-time lawyer with political ambitions, sees the crime as his ticket to the Senate if he can find the right victim to finger for the crime. He sets out to convict Robert Hale, a transplanted northerner who was Mary's teacher at the business school where she was killed. Despite the fact that all the evidence against Hale is circumstantial, Griffin works with a ruthless reporter to create a media frenzy of prejudice and hate against the teacher.",
#   'languages': ['English'],
#   'released': datetime.datetime(1937, 10, 9, 0, 0),
#   'directors': ['Mervyn LeRoy'],
#   'writers': ['Ward Greene (novel)',
#    'Robert Rossen (screen play)',
#    'Aben Kandel (screen play)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-05-10 00:40:53.917000000',
#   'year': 1937,
#   'imdb': {'rating': 7.4, 'votes': 926, 'id': 29658},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 146, 'meter': 83},
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 26, 40)}},
#  {'_id': ObjectId('573a1392f29313caabcdb5a9'),
#   'plot': 'A priest tries to stop a gangster from corrupting a group of street kids.',
#   'genres': ['Crime', 'Drama', 'Film-Noir'],
#   'runtime': 97,
#   'rated': 'APPROVED',
#   'cast': ['James Cagney', "Pat O'Brien", 'Humphrey Bogart', 'Ann Sheridan'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BY2JhZmJmOTQtMjg5Ni00N2M4LTlkNDAtOTc0ZGQ2MTJhNDM4XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Angels with Dirty Faces',
#   'fullplot': "Rocky Sullivan and Jerry Connolly were tough kids who grew up together in the toughest part of New York --- Hell's Kitchen. Early on, Rocky gets sent to reform school, where he learns how to be a first class criminal. Jerry, who had escaped from the law, goes straight and becomes a priest. As adults, they reunite in the old neighborhood: Jerry works with the kids who, like he and Rocky, could end up on either side of the law. Rocky has returned looking for a safe place to stay till he can get back into his old racketeering organization -- something that his old partner isn't anxious to have happen. Lots of rapid fire wisecracks, roughhousing and gunfire ensues.",
#   'languages': ['English'],
#   'released': datetime.datetime(1938, 11, 26, 0, 0),
#   'directors': ['Michael Curtiz'],
#   'writers': ['John Wexley (screen play)',
#    'Warren Duff (screen play)',
#    'Rowland Brown (from a story by)'],
#   'awards': {'wins': 4,
#    'nominations': 0,
#    'text': 'Nominated for 3 Oscars. Another 1 win.'},
#   'lastupdated': '2015-08-30 00:44:33.900000000',
#   'year': 1938,
#   'imdb': {'rating': 8.0, 'votes': 15019, 'id': 29870},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 9355, 'meter': 92},
#    'dvd': datetime.datetime(2005, 1, 25, 0, 0),
#    'critic': {'rating': 8.0, 'numReviews': 20, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 13, 17, 30, 48),
#    'rotten': 0,
#    'production': 'Warner Bros. Pictures',
#    'fresh': 20}},
#  {'_id': ObjectId('573a1392f29313caabcdbdd3'),
#   'plot': 'Davey Fenwick leaves his mining village on a university scholarship intent on returning to better support the miners against the owners. But he falls in love with Jenny who gets him to ...',
#   'genres': ['Drama'],
#   'runtime': 110,
#   'cast': ['Michael Redgrave',
#    'Margaret Lockwood',
#    'Emlyn Williams',
#    'Nancy Price'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNzI0ODk3NzU4Nl5BMl5BanBnXkFtZTgwMTQ4ODgwMzE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Stars Look Down',
#   'fullplot': 'Davey Fenwick leaves his mining village on a university scholarship intent on returning to better support the miners against the owners. But he falls in love with Jenny who gets him to marry her and return home as local schoolteacher before finishing his degree. Davey finds he is ill-at-ease in his role, the more so when he realises Jenny still loves her former boyfriend. When he finds that his father and the other miners are going to have to continue working on a possibly deadly coal seam he decides to act.',
#   'languages': ['English'],
#   'released': datetime.datetime(1940, 9, 16, 0, 0),
#   'directors': ['Carol Reed'],
#   'writers': ['A.J. Cronin (from the book by)',
#    'J.B. Williams (screenplay)',
#    'A.J. Cronin (adaptation)',
#    'J.B. Williams (scenario)',
#    'A. Coppel (scenario)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-09-02 00:42:27.583000000',
#   'year': 1940,
#   'imdb': {'rating': 7.2, 'votes': 634, 'id': 31976},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 330, 'meter': 56},
#    'fresh': 7,
#    'critic': {'rating': 7.8, 'numReviews': 8, 'meter': 88},
#    'rotten': 1,
#    'lastUpdated': datetime.datetime(2015, 4, 30, 19, 14, 20)}},
#  {'_id': ObjectId('573a1393f29313caabcdbeca'),
#   'countries': ['Italy', 'Spain'],
#   'genres': ['Drama', 'History', 'War'],
#   'runtime': 112,
#   'cast': ['Fosco Giachetti', 'Mireille Balin', 'Marèa Denis', 'Rafael Calvo'],
#   'num_mflix_comments': 0,
#   'title': 'The Siege of the Alcazar',
#   'lastupdated': '2015-04-13 01:18:38.917000000',
#   'languages': ['Italian'],
#   'released': datetime.datetime(1940, 8, 20, 0, 0),
#   'directors': ['Augusto Genina'],
#   'writers': ['Augusto Genina (story)',
#    'Alessandro De Stefani (story)',
#    'Pietro Caporilli (story)',
#    'Augusto Genina (screenplay)',
#    'Alessandro De Stefani (screenplay)',
#    'Edoardo Anton (Italian dialogue)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'year': 1940,
#   'imdb': {'rating': 6.4, 'votes': 109, 'id': 32225},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 2724, 'meter': 75},
#    'dvd': datetime.datetime(2000, 8, 22, 0, 0),
#    'critic': {'rating': 8.6, 'numReviews': 21, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 14, 19, 37, 36),
#    'rotten': 0,
#    'production': 'MCA Universal Home Video',
#    'fresh': 21}},
#  {'_id': ObjectId('573a1393f29313caabcdbed0'),
#   'plot': 'A dashing pilot and a vivacious reporter have romantic and dramatic adventures in Europe as World War II begins.',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'runtime': 110,
#   'rated': 'PASSED',
#   'cast': ['Claudette Colbert',
#    'Ray Milland',
#    "Dennis O'Keefe",
#    'Walter Abel'],
#   'num_mflix_comments': 1,
#   'title': 'Arise, My Love',
#   'fullplot': "In 1939, American Tom Martin, who fought in the Spanish Civil War, awaits execution at the hands of the Fascist victors when reporter Augusta 'Gusto' Nash, for a scoop, aids him in an audacious escape. Of course, Tom tries to romance Gusto; but though she likes him, her career comes first, and Tom himself prefers freedom-fighting to settling down. Comedy becomes drama as their mixed feelings lead them on a circuitous path through the deepening chaos and catastrophe of the early days of World War II.",
#   'languages': ['English', 'French', 'German', 'Spanish'],
#   'released': datetime.datetime(1940, 11, 8, 0, 0),
#   'directors': ['Mitchell Leisen'],
#   'writers': ['Charles Brackett (screen play)',
#    'Billy Wilder (screen play)',
#    'Jacques Thèry (adaptation)',
#    'Benjamin Glazer (original story)',
#    'Hans Szèkely (original story)'],
#   'awards': {'wins': 0,
#    'nominations': 4,
#    'text': 'Won 1 Oscar. Another 3 nominations.'},
#   'lastupdated': '2015-07-21 08:16:03.510000000',
#   'year': 1940,
#   'imdb': {'rating': 7.0, 'votes': 518, 'id': 32220},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 177, 'meter': 59},
#    'lastUpdated': datetime.datetime(2015, 6, 29, 18, 33, 9)}},
#  {'_id': ObjectId('573a1393f29313caabcdbed5'),
#   'plot': 'Henpecked Egbert Sousè has comic adventures as a substitute film director and unlikely bank guard.',
#   'genres': ['Comedy'],
#   'runtime': 72,
#   'rated': 'APPROVED',
#   'cast': ['W.C. Fields', 'Cora Witherspoon', 'Una Merkel', 'Evelyn Del Rio'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYzQwNzVlNGItZDJjMi00NTRlLTg3YjktZTU4Y2VjNTdmMDUzXkEyXkFqcGdeQXVyMTk2MzI2Ng@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Bank Dick',
#   'fullplot': 'Egbert Sousè, "accent grave over the e", henpecked by his whole family, is recruited to replace a drunken film director, then seems to have captured a bank robber and is hired as guard in the Lompoc Bank, where Og Oggilby, his daughter\'s fiancèe, is teller. Sousè persuades Og to embezzle $500 to buy phony stock; then the bank examiner shows up. Can Sousè keep him occupied for four days? The climax is an extended chase sequence.',
#   'languages': ['English'],
#   'released': datetime.datetime(1940, 11, 29, 0, 0),
#   'directors': ['Edward F. Cline'],
#   'writers': ['W.C. Fields (original screen play)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-09-12 00:17:59.070000000',
#   'year': 1940,
#   'imdb': {'rating': 7.4, 'votes': 5006, 'id': 32234},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 2724, 'meter': 75},
#    'dvd': datetime.datetime(2000, 8, 22, 0, 0),
#    'critic': {'rating': 8.6, 'numReviews': 21, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 14, 19, 37, 36),
#    'rotten': 0,
#    'production': 'MCA Universal Home Video',
#    'fresh': 21}},
#  {'_id': ObjectId('573a1393f29313caabcdbef1'),
#   'plot': "Two little boys have faith in a dog they name Promise, so much faith that they enter him in the championship trials for bird dogs. The favorite is Georgia Boy bred and trained by the boys' ...",
#   'genres': ['Drama', 'Family'],
#   'runtime': 81,
#   'rated': 'PASSED',
#   'cast': ['Billy Lee', 'Cordell Hickman', 'Richard Lane', 'Lester Matthews'],
#   'num_mflix_comments': 1,
#   'title': 'The Biscuit Eater',
#   'fullplot': "Two little boys have faith in a dog they name Promise, so much faith that they enter him in the championship trials for bird dogs. The favorite is Georgia Boy bred and trained by the boys' fathers. And if Georgia Boy doesn't win, the fathers may both lose their jobs.",
#   'languages': ['English'],
#   'released': datetime.datetime(1940, 5, 24, 0, 0),
#   'directors': ['Stuart Heisler'],
#   'writers': ['Stuart Anthony (screen play)',
#    'Lillie Hayward (screen play)',
#    'James H. Street (based on a story by)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-07-27 00:15:16.370000000',
#   'year': 1940,
#   'imdb': {'rating': 7.1, 'votes': 158, 'id': 32254},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 75, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 27, 19, 40, 23)}},
#  {'_id': ObjectId('573a1393f29313caabcdbef6'),
#   'plot': "Dr. Sovac transplants the brain of a gangster into his professor friend's body to save his life, but there is a side effect that causes a dangerous split personality.",
#   'genres': ['Drama', 'Horror', 'Sci-Fi'],
#   'runtime': 70,
#   'rated': 'APPROVED',
#   'cast': ['Boris Karloff', 'Bela Lugosi', 'Stanley Ridges', 'Anne Nagel'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZmI5NzFlY2EtOTA5OS00MzYwLWE4MTAtMDI5NmJlZTYzNTJmXkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Black Friday',
#   'fullplot': "When his friend Professor Kingsley is at deaths door, brain surgeon Dr. Sovac saves his life by means of an illegal operation that transplants part of injured gangster Red Cannon's brain. Unfortunately, the operation has a disastrous Jeckll and Hyde side effect and under certain conditions the persona of Cannon emerges. Sovac soon learns of the duel personality and of half a million dollars the gangster has hidden away. He attempts to find the money through the manipulation of his friend, an attempt that brings Kingsley closer to madness as he alternates between a meek professor of English and a brutal gangster out for murderous revenge on those who tried to kill him.",
#   'languages': ['English'],
#   'released': datetime.datetime(1940, 4, 12, 0, 0),
#   'directors': ['Arthur Lubin'],
#   'writers': ['Curt Siodmak (screenplay)', 'Eric Taylor (screenplay)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-08-28 00:13:05.830000000',
#   'year': 1940,
#   'imdb': {'rating': 6.3, 'votes': 1121, 'id': 32258},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 711, 'meter': 47},
#    'dvd': datetime.datetime(1995, 8, 8, 0, 0),
#    'production': 'Passport',
#    'lastUpdated': datetime.datetime(2015, 8, 4, 20, 5, 37)}},
#  {'_id': ObjectId('573a1393f29313caabcdbf6c'),
#   'plot': "Judy O'Brien is an aspiring ballerina in a dance troupe. Also in the company is Bubbles, a brash mantrap who leaves the struggling troupe for a career in burlesque. When the company ...",
#   'genres': ['Comedy', 'Drama', 'Musical'],
#   'runtime': 90,
#   'rated': 'APPROVED',
#   'cast': ["Maureen O'Hara",
#    'Louis Hayward',
#    'Lucille Ball',
#    'Virginia Field'],
#   'num_mflix_comments': 2,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZDhhYjZkYzEtNGZkNS00NzUxLWJmODMtYjFjZDJlMTQyNjAzL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Dance, Girl, Dance',
#   'fullplot': "Judy O'Brien is an aspiring ballerina in a dance troupe. Also in the company is Bubbles, a brash mantrap who leaves the struggling troupe for a career in burlesque. When the company disbands, Bubbles gives Judy a thankless job as her stooge. The two eventually clash when both fall for the same man.",
#   'languages': ['English'],
#   'released': datetime.datetime(1940, 8, 30, 0, 0),
#   'directors': ['Dorothy Arzner', 'Roy Del Ruth'],
#   'writers': ['Tess Slesinger (screen play)',
#    'Frank Davis (screen play)',
#    'Vicki Baum (story)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-08-08 00:56:43.740000000',
#   'year': 1940,
#   'imdb': {'rating': 6.6, 'votes': 1122, 'id': 32376},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 480, 'meter': 64},
#    'dvd': datetime.datetime(2007, 6, 19, 0, 0),
#    'production': 'WARNER BROTHERS PICTURES',
#    'lastUpdated': datetime.datetime(2015, 8, 25, 18, 21, 16)}},
#  {'_id': ObjectId('573a1393f29313caabcdbf81'),
#   'plot': 'An experimental film of dots animated by being drawn directly on filmstock.',
#   'genres': ['Short', 'Animation'],
#   'runtime': 3,
#   'title': 'Dots',
#   'countries': ['Canada'],
#   'fullplot': 'An experimental film of dots animated by being drawn directly on filmstock.',
#   'num_mflix_comments': 0,
#   'directors': ['Norman McLaren'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-05-31 00:01:35.230000000',
#   'year': 1940,
#   'imdb': {'rating': 6.1, 'votes': 475, 'id': 32408},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 120, 'meter': 55},
#    'dvd': datetime.datetime(2006, 6, 13, 0, 0),
#    'production': '20th Century Fox Film Corporation',
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 15, 5)}},
#  {'_id': ObjectId('573a1393f29313caabcdbf82'),
#   'plot': 'An American girl on vacation in Argentina falls for a wealthy racehorse owner.',
#   'genres': ['Comedy', 'Drama', 'Musical'],
#   'runtime': 89,
#   'rated': 'APPROVED',
#   'cast': ['Don Ameche',
#    'Betty Grable',
#    'Carmen Miranda',
#    'Charlotte Greenwood'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZGM2M2JhNWYtNDE2Zi00NjkyLTg4Y2EtZjdlZGRiNWNmNGQ2XkEyXkFqcGdeQXVyNjE5MjUyOTM@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Down Argentine Way',
#   'fullplot': 'An American girl on vacation in Argentina falls for a wealthy racehorse owner.',
#   'languages': ['English'],
#   'released': datetime.datetime(1940, 10, 11, 0, 0),
#   'directors': ['Irving Cummings'],
#   'writers': ['Darrell Ware (screen play)',
#    'Karl Tunberg (screen play)',
#    'Rian James (story)',
#    'Ralph Spence (story)'],
#   'awards': {'wins': 4,
#    'nominations': 0,
#    'text': 'Nominated for 3 Oscars. Another 1 win.'},
#   'lastupdated': '2015-09-16 08:23:06.087000000',
#   'year': 1940,
#   'imdb': {'rating': 6.7, 'votes': 665, 'id': 32410},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 120, 'meter': 55},
#    'dvd': datetime.datetime(2006, 6, 13, 0, 0),
#    'production': '20th Century Fox Film Corporation',
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 15, 5)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdbfb0'),
#   'plot': 'A collection of animated interpretations of great works of Western classical music.',
#   'genres': ['Animation', 'Family', 'Fantasy'],
#   'runtime': 125,
#   'rated': 'G',
#   'cast': ['Leopold Stokowski', 'Deems Taylor'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYjhlYzNkOGEtZjNkZC00OTQ4LWJiMzEtMTM3YzBiM2FkMDUxXkEyXkFqcGdeQXVyNzY1NDgwNjQ@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Fantasia',
#   'fullplot': 'Disney animators set pictures to Western classical music as Leopold Stokowski conducts the Philadelphia Orchestra. "The Sorcerer\'s Apprentice" features Mickey Mouse as an aspiring magician who oversteps his limits. "The Rite of Spring" tells the story of evolution, from single-celled animals to the death of the dinosaurs. "Dance of the Hours" is a comic ballet performed by ostriches, hippos, elephants, and alligators. "Night on Bald Mountain" and "Ave Maria" set the forces of darkness and light against each other as a devilish revel is interrupted by the coming of a new day.',
#   'languages': ['English'],
#   'released': datetime.datetime(1940, 12, 25, 0, 0),
#   'directors': ['Norman Ferguson',
#    'James Algar',
#    'Samuel Armstrong',
#    'Ford Beebe Jr.',
#    'Jim Handley',
#    'T. Hee',
#    'Wilfred Jackson',
#    'Hamilton Luske',
#    'Bill Roberts',
#    'Paul Satterfield',
#    'Ben Sharpsteen'],
#   'writers': ['Joe Grant (story)',
#    'Dick Huemer (story)',
#    'Lee Blair (story)',
#    'Elmer Plummer (story)',
#    'Phil Dike (story)',
#    'Sylvia Moberly-Holland (story)',
#    'Norman Wright (story)',
#    'Albert Heath (story)',
#    'Bianca Majolie (story)',
#    'Graham Heid (story)',
#    'Perce Pearce (story)',
#    'Carl Fallberg (story)',
#    'William Martin (story)',
#    'Leo Thiele (story)',
#    'Robert Sterner (story)',
#    'John McLeish (story)',
#    'Otto Englander (story)',
#    'Webb Smith (story)',
#    'Erdman Penner (story)',
#    'Joseph Sabo (story)',
#    'Bill Peet (story)',
#    'Vernon Stallings (story)',
#    'Campbell Grant (story)',
#    'Arthur Heinemann (story)',
#    'Phil Dike (story)'],
#   'awards': {'wins': 7, 'nominations': 1, 'text': '7 wins & 1 nomination.'},
#   'lastupdated': '2015-09-10 17:06:36.233000000',
#   'year': 1940,
#   'imdb': {'rating': 7.8, 'votes': 66572, 'id': 32455},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 127798, 'meter': 83},
#    'dvd': datetime.datetime(1991, 11, 1, 0, 0),
#    'critic': {'rating': 8.6, 'numReviews': 50, 'meter': 96},
#    'lastUpdated': datetime.datetime(2015, 9, 10, 17, 6, 37),
#    'consensus': "A landmark in animation (and a huge influence on the medium of music video), Disney's Fantasia is a relentlessly inventive blend of the classics with phantasmagorical images.",
#    'rotten': 2,
#    'production': 'Walt Disney Productions',
#    'fresh': 48},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdc030'),
#   'plot': "Dictator Adenoid Hynkel tries to expand his empire while a poor Jewish barber tries to avoid persecution from Hynkel's regime.",
#   'genres': ['Comedy', 'Drama', 'War'],
#   'runtime': 125,
#   'rated': 'APPROVED',
#   'cast': ['Charles Chaplin',
#    'Jack Oakie',
#    'Reginald Gardiner',
#    'Henry Daniell'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMmExYWJjNTktNGUyZS00ODhmLTkxYzAtNWIzOGEyMGNiMmUwXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Great Dictator',
#   'fullplot': "Twenty years after the end of WWI in which the nation of Tomainia was on the losing side, Adenoid Hynkel has risen to power as the ruthless dictator of the country. He believes in a pure Aryan state, and the decimation of the Jews. This situation is unknown to a simple Jewish-Tomainian barber who has since been hospitalized the result of a WWI battle. Upon his release, the barber, who had been suffering from memory loss about the war, is shown the new persecuted life of the Jews by many living in the Jewish ghetto, including a washerwoman named Hannah, with whom he begins a relationship. The barber is ultimately spared such persecution by Commander Schultz, who he saved in that WWI battle. The lives of all Jews in Tomainia are eventually spared with a policy shift by Hynkel himself, who is doing so for ulterior motives. But those motives include a want for world domination, starting with the invasion of neighboring Osterlich, which may be threatened by Benzino Napaloni, the dictator of neighboring Bacteria. Ultimately Schultz, who has turned traitor against Hynkel's regime, and the barber, may be able to join forces to take control of the situation, they using Schultz's inside knowledge of the workings of the regime and the barber's uncanny resemblance to one of those in power.",
#   'languages': ['English', 'Esperanto'],
#   'released': datetime.datetime(1941, 3, 7, 0, 0),
#   'directors': ['Charles Chaplin'],
#   'writers': ['Charles Chaplin'],
#   'awards': {'wins': 10,
#    'nominations': 1,
#    'text': 'Nominated for 5 Oscars. Another 5 wins & 1 nomination.'},
#   'lastupdated': '2015-09-14 09:47:08.293000000',
#   'year': 1940,
#   'imdb': {'rating': 8.5, 'votes': 119966, 'id': 32553},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 42912, 'meter': 95},
#    'dvd': datetime.datetime(2010, 5, 10, 0, 0),
#    'critic': {'rating': 8.8, 'numReviews': 37, 'meter': 92},
#    'lastUpdated': datetime.datetime(2015, 9, 16, 19, 41, 26),
#    'rotten': 3,
#    'production': 'Criterion Collection',
#    'fresh': 34}},
#  {'_id': ObjectId('573a1393f29313caabcdc04b'),
#   'plot': 'A newspaper editor uses every trick in the book to keep his ace reporter ex-wife from remarrying.',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'runtime': 92,
#   'rated': 'APPROVED',
#   'cast': ['Cary Grant', 'Rosalind Russell', 'Ralph Bellamy', 'Gene Lockhart'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BOTU4ODdjNDYtZjk0Zi00ZDBmLTllODEtMzQ5NmYzZGEzNjVlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'His Girl Friday',
#   'fullplot': "Having been away for four months, Hildy Johnson walks into the offices of the New York City based The Morning Post, where she is a star reporter, to tell her boss, editor Walter Burns, that she is quitting. The reason for her absence was among other things to get a Reno divorce, from, of all people, Walter, who admits he was a bad husband. Hildy divorced Walter largely because she wanted more of a home life, whereas Walter saw her more as a driven hard-boiled reporter than subservient homemaker. Hildy has also come to tell Walter that she is taking the afternoon train to Albany, where she will be getting married tomorrow to staid straight-laced insurance agent, Bruce Baldwin, with whose mother they will live, at least for the first year. Walter doesn't want to lose Hildy, either as a reporter or a wife, and if he does, doesn't believe Bruce is worthy of her. Walter does whatever he can at least to delay Hildy and Bruce's trip, long enough to persuade Hildy to stay for good. His plan includes doing whatever he can to place Bruce in a bad light, while dangling a big story under her nose, namely covering what the newspaper believes is the unfair imminent execution of convicted cop killer, Earl Williams. Hildy doesn't trust Walter in dealing with her and Bruce in an above board manner, but the lure of what potentially may become the biggest story in years, which includes true love, a bumbling sheriff and a corrupt mayor, the latter's actions largely in light of an upcoming election, may prove to be too much for Hildy to resist, especially if it ends up being an exclusive. Regardless of the story outcome, Hildy will have to decide if the thrill of the chase was worth the anguish on her personal life.",
#   'languages': ['English', 'French'],
#   'released': datetime.datetime(1940, 1, 18, 0, 0),
#   'directors': ['Howard Hawks'],
#   'writers': ['Charles Lederer (screen play)',
#    'Ben Hecht (from the play "The Front Page")',
#    'Charles MacArthur (from the play "The Front Page")'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-09-01 01:18:49.693000000',
#   'year': 1940,
#   'imdb': {'rating': 8.1, 'votes': 38493, 'id': 32599},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 23603, 'meter': 90},
#    'dvd': datetime.datetime(2004, 12, 28, 0, 0),
#    'critic': {'rating': 8.8, 'numReviews': 39, 'meter': 97},
#    'lastUpdated': datetime.datetime(2015, 9, 13, 9, 51, 47),
#    'consensus': 'Anchored by stellar performances from Cary Grant and Rosalind Russell, His Girl Friday is a classic screwball romantic comedy.',
#    'rotten': 1,
#    'production': 'Columbia Pictures',
#    'fresh': 38}},
#  {'_id': ObjectId('573a1393f29313caabcdc076'),
#   'plot': 'In this notorious Nazi propaganda historical costume melodrama, a conniving, ambitious Jewish businessman, Sèè Oppenheimer, snares a post as treasurer to the Duke of Wurttemburg by ...',
#   'genres': ['Drama'],
#   'runtime': 98,
#   'cast': ['Ferdinand Marian',
#    'Kristina Sèderbaum',
#    'Heinrich George',
#    'Werner Krauss'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZjc1YjY0MTgtODgwZi00ZmJiLWJiODgtOGRmYmI4NjYyNTExXkEyXkFqcGdeQXVyMjA0MzYwMDY@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Jud Sèè',
#   'fullplot': 'In this notorious Nazi propaganda historical costume melodrama, a conniving, ambitious Jewish businessman, Sèè Oppenheimer, snares a post as treasurer to the Duke of Wurttemburg by showering the corrupt duke with treasure and promises of even greater riches. As the Jew\'s schemes grow more elaborate and his actions more brazen, the dukedom nearly erupts into civil war. Persuaded by the Jew, the Duke all but scuttles the constitution and alienates the assembly by lifting the local ban on Jews in Stuttgart. In a final outrage, the Jew rapes a wholesome German girl and tortures her father and fiancèe. When the Duke succumbs to a sudden heart attack, the assembly of Elders try the Jew and sentence him to death for having "carnal knowledge of a Christian woman".',
#   'languages': ['German'],
#   'released': datetime.datetime(1941, 1, 23, 0, 0),
#   'directors': ['Veit Harlan'],
#   'writers': ['Veit Harlan (screenplay)',
#    'Eberhard Wolfgang Moeller (screenplay)',
#    'Ludwig Metzger (screenplay)',
#    'R.L. Migeon (French version)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-08-19 00:30:45.750000000',
#   'year': 1940,
#   'imdb': {'rating': 5.2, 'votes': 1238, 'id': 32653},
#   'countries': ['Germany'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 2.5, 'numReviews': 92, 'meter': 27},
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 59, 14)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdc093'),
#   'plot': 'Kitty Foyle, a hard-working white-collar girl from a Philadelphia, Pennsylvania low, middle-class family, meets and falls in love with young socialite Wyn Strafford but his family is against her.',
#   'genres': ['Drama', 'Romance'],
#   'runtime': 108,
#   'rated': 'APPROVED',
#   'cast': ['Ginger Rogers',
#    'Dennis Morgan',
#    'James Craig',
#    'Eduardo Ciannelli'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BODZkZTcwNzQtODBiNy00ZTNjLTlhMjctZDViZjQzMGIyZDg5XkEyXkFqcGdeQXVyNjc0MzMzNjA@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Kitty Foyle',
# ...
#    'Eric Gurney (story)',
#    'Sylvia Moberly-Holland (story)',
#    'T. Hee (story)',
#    'Erdman Penner (story)',
#    'Dick Kelsey (story)',
#    'James Bodrero (story)',
#    'Roy Williams (story)',
#    'Cap Palmer (story)',
#    'Jesse Marsh (story)',
#    'Erwin Graham (story)'],
#   'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'},
#   'lastupdated': '2015-08-30 03:58:01.037000000',
#   'year': 1946,
#   'imdb': {'rating': 6.5, 'votes': 2033, 'id': 38718},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.1, 'numReviews': 2273, 'meter': 43},
#    'dvd': datetime.datetime(2000, 6, 6, 0, 0),
#    'critic': {'rating': 6.3, 'numReviews': 9, 'meter': 67},
#    'lastUpdated': datetime.datetime(2015, 8, 31, 18, 53, 52),
#    'consensus': "This collection of musical-themed shorts doesn't reach the artistic heights of Fantasia, but it's well animated and mostly good fun.",
#    'rotten': 3,
#    'fresh': 6},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a139df29313caabcf8f76'),
#   'plot': 'The films takes an expressionist look at the gulf between the rich and poor in the society. The film centers on a wealthy and capacious landlord, Sarkar (Rafi Peer) who lives in a palatial ...',
#   'runtime': 122,
#   'cast': ['Rafiq Anwar', 'Uma Anand', 'Kamini Kaushal', 'Rafi Peer'],
#   'title': 'Neecha Nagar',
#   'fullplot': "The films takes an expressionist look at the gulf between the rich and poor in the society. The film centers on a wealthy and capacious landlord, Sarkar (Rafi Peer) who lives in a palatial estate high up on a mountain while the poor toil and starve in the valley below. The villagers of 'Neecha Nagar' harbor hate for Sarkar and their hatred is fueled even more by the fact that Sarkar plans to direct all the sewage into the village in order to make way for his housing project. The villagers protest this move with their head, Balraj (Rafiq Anwar) leading a movement against Sarkar's plan. Sarkar's daughter Maya (Uma Anand) joins the movement against her father and falls in love with Balraj. With the sewage flowing through the village, epidemic starts to spread and the lives of the villagers comes under threat. Can poor people of 'Neecha Nagar' survive the greed and wickedness of the rich? Can Sarkar and his malicious ways be put to an end?",
#   'languages': ['Hindi'],
#   'released': datetime.datetime(1946, 9, 1, 0, 0),
#   'directors': ['Chetan Anand'],
#   'writers': ['Hayatulla Ansari (story)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-05-30 00:35:30.953000000',
#   'year': 1946,
#   'imdb': {'rating': 7.7, 'votes': 66, 'id': 154942},
#   'countries': ['India'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 63, 'meter': 71},
#    'dvd': datetime.datetime(2006, 10, 3, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 7, 20, 0, 31)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a139df29313caabcfa6cd'),
#   'plot': "Cantinflas is a private, who doesn't know anything about discipline or following rules. He only wants to think about his girlfriend, the maid in an opulent hacienda. The owner has an ugly ...",
#   'genres': ['Comedy'],
#   'runtime': 113,
#   'cast': ['Cantinflas',
#    'èngel Garasa',
#    "Daniel 'Chino' Herrera",
#    'Andrès Soler'],
#   'num_mflix_comments': 0,
#   'title': 'èA volar joven!',
#   'fullplot': "Cantinflas is a private, who doesn't know anything about discipline or following rules. He only wants to think about his girlfriend, the maid in an opulent hacienda. The owner has an ugly and shy daughter, who is in love with Cantinflas. The problems arrive when the family arrange a wedding between the ugly girl and Cantinflas, who in order to avoid the commitment causes himself an arrest. During the punishment, Cantinflas will learn to fly with a silly and not to much trained instructor.",
#   'languages': ['Spanish'],
#   'released': datetime.datetime(1947, 12, 25, 0, 0),
#   'directors': ['Miguel M. Delgado'],
#   'writers': ['Paul Colline (story)',
#    'Miguel M. Delgado (screenplay)',
#    'Jaime Salvador (adaptation)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-08-31 00:20:25.403000000',
#   'year': 1947,
#   'imdb': {'rating': 7.2, 'votes': 183, 'id': 161215},
#   'countries': ['Mexico'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.stealthismovie.net',
#    'viewer': {'rating': 3.6, 'numReviews': 2912, 'meter': 72},
#    'dvd': datetime.datetime(2001, 4, 24, 0, 0),
#    'critic': {'rating': 5.4, 'numReviews': 43, 'meter': 51},
#    'lastUpdated': datetime.datetime(2015, 9, 10, 18, 49, 15),
#    'consensus': "D'Onofrio's performance fails to do justice to Hoffman, and the depiction of the 60s also rings false.",
#    'rotten': 21,
#    'production': 'LionsGate Entertainment',
#    'fresh': 22}},
#  {'_id': ObjectId('573a139ef29313caabcfd5ef'),
#   'plot': 'The World War II US Government account of the European theatre of the war from after the English and French entry to the fall of France.',
#   'genres': ['Documentary', 'History', 'War'],
#   'runtime': 57,
#   'title': 'Divide and Conquer',
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTczNzE1MTQ4MF5BMl5BanBnXkFtZTgwNjM1MzgwMzE@._V1._CR47,47,266,392_SY264_CR0,0,178,264_AL_.jpg',
#   'countries': ['USA'],
#   'fullplot': 'In this episode of the Why We Fight propaganda series, the events from the English and French declarations of war against Nazi Germany to the conquest of France by the Nazi. In detail, we learn of how a combination of innovative Nazi military tactics and the work of traitors allowed the conquest of much of Central Europe.',
#   'languages': ['English'],
#   'cast': ['General Bergeret',
#    'Karl Brandt',
#    'Winston Churchill',
#    'Warren J. Clear'],
#   'directors': ['Frank Capra', 'Anatole Litvak'],
#   'awards': {'wins': 2, 'nominations': 0, 'text': '2 wins.'},
#   'lastupdated': '2015-08-27 00:01:32.400000000',
#   'year': 1943,
#   'imdb': {'rating': 7.4, 'votes': 434, 'id': 173769},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 204, 'meter': 64},
#    'dvd': datetime.datetime(1998, 10, 13, 0, 0),
#    'production': 'Roy Frumkes Productions',
#    'lastUpdated': datetime.datetime(2015, 9, 3, 19, 49, 15)}},
#  {'_id': ObjectId('573a139ff29313caabcff7d1'),
#   'plot': "The official World War II US government account of Great Britain's stand against the Nazi war machine after the Dunkirk evacuation.",
#   'genres': ['Documentary', 'History', 'War'],
#   'runtime': 54,
#   'cast': ['Douglas Bader',
#    'Arno Breker',
#    'Winston Churchill',
#    'Hermann Gèring'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTgzMzQwMTYwOV5BMl5BanBnXkFtZTgwOTk2NDgwMzE@._V1._CR41,48,282,391_SY132_CR3,0,89,132_AL_.jpg',
#   'title': 'The Battle of Britain',
#   'fullplot': 'In this installment of the "Why We Fight" propaganda film series, we have the account of Great Britain\'s last stand against the forces of Nazi Germany. This mainly focuses on the desperate, but successful, battle to maintain their vital air superiority over the British Isles and the morale of the people to prevent invasion.',
#   'languages': ['English'],
#   'released': datetime.datetime(1945, 11, 26, 0, 0),
#   'directors': ['Frank Capra', 'Anthony Veiller'],
#   'writers': ['Julius J. Epstein', 'Philip G. Epstein'],
#   'awards': {'wins': 2, 'nominations': 0, 'text': '2 wins.'},
#   'lastupdated': '2015-08-13 00:25:33.130000000',
#   'year': 1943,
#   'imdb': {'rating': 7.5, 'votes': 497, 'id': 182766},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 80, 'meter': 67},
#    'dvd': datetime.datetime(2004, 7, 6, 0, 0),
#    'production': 'US Army',
#    'lastUpdated': datetime.datetime(2015, 8, 12, 19, 2, 43)}},
#  {'_id': ObjectId('573a139ff29313caabcff8ae'),
#   'plot': 'The World War II US Government account of the European theatre of the war from after the English and French entry to the fall of France.',
#   'genres': ['Documentary', 'History', 'War'],
#   'runtime': 57,
#   'title': 'Divide and Conquer',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTczNzE1MTQ4MF5BMl5BanBnXkFtZTgwNjM1MzgwMzE@._V1._CR47,47,266,392_SY264_CR0,0,178,264_AL_.jpg',
#   'countries': ['USA'],
#   'fullplot': 'In this episode of the Why We Fight propaganda series, the events from the English and French declarations of war against Nazi Germany to the conquest of France by the Nazi. In detail, we learn of how a combination of innovative Nazi military tactics and the work of traitors allowed the conquest of much of Central Europe.',
#   'languages': ['English'],
#   'cast': ['General Bergeret',
#    'Karl Brandt',
#    'Winston Churchill',
#    'Warren J. Clear'],
#   'directors': ['Frank Capra', 'Anatole Litvak'],
#   'awards': {'wins': 2, 'nominations': 0, 'text': '2 wins.'},
#   'lastupdated': '2015-05-11 00:01:41.183000000',
#   'year': 1943,
#   'imdb': {'rating': 7.4, 'votes': 421, 'id': 182989},
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.thedogwalker.com',
#    'viewer': {'rating': 3.0, 'numReviews': 34},
#    'dvd': datetime.datetime(2003, 11, 25, 0, 0),
#    'critic': {'rating': 4.8, 'numReviews': 10, 'meter': 50},
#    'lastUpdated': datetime.datetime(2015, 6, 15, 18, 33, 46),
#    'rotten': 5,
#    'production': 'Outrider Pictures',
#    'fresh': 5},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a139ff29313caabcffc7d'),
#   'plot': 'Part VII of the "Why We Fight" series of wartime documentaries. This entry attempts to describe the factors leading up to America\'s entry into the Second World War.',
#   'genres': ['Documentary', 'War'],
#   'runtime': 70,
#   'cast': ['Dean Acheson', 'General Bergeret', 'A.A. Berle', 'Arno Breker'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTc4NjI1NzM3OV5BMl5BanBnXkFtZTcwNzg4NjcyMQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'War Comes to America',
#   'fullplot': 'In this final installment of the "Why We Fight" propaganda series, the subject focuses on the United States of America. We learn of its good qualities and the things worth fighting for. With that established, we learn of the history of the United States\' population shifting opinion towards siding with the Allies against the Axis until the attack on Pearl Harbour which brought America into full scale involvement in the war.',
#   'languages': ['English'],
#   'released': datetime.datetime(1945, 6, 14, 0, 0),
#   'directors': ['Frank Capra', 'Anatole Litvak'],
#   'writers': ['Julius J. Epstein',
#    'Philip G. Epstein',
#    'Adolf Hitler (book)',
#    'Anatole Litvak',
#    'Anthony Veiller'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-08-25 00:02:31.697000000',
#   'year': 1945,
#   'imdb': {'rating': 7.1, 'votes': 410, 'id': 183997},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 30},
#    'production': 'Indican Pictures',
#    'lastUpdated': datetime.datetime(2015, 5, 10, 18, 27, 19)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a139ff29313caabcffd74'),
#   'plot': 'The Official World War II US Government account of Chinese defense against Japanese aggression.',
#   'genres': ['Documentary', 'History', 'War'],
#   'runtime': 65,
#   'cast': ['Claire Chennault', 'Kai-Shek Chiang', 'Madame Chiang', 'Teh Chu'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjA4MjIyMzQyOV5BMl5BanBnXkFtZTcwMDI3MDc0NQ@@._V1._CR35,33,281,418_SX178_AL_.jpg',
#   'title': 'The Battle of China',
#   'fullplot': 'In this installment of the "Why We Fight" propaganda series, we learn about the country of China and its people. With a brief history of the country, we also learn of why the Japanese wanted to conquer it and felt confident about succeeding. Finally, the history of the war in that theatre is illustrated and shows the stiff determination of the Chinese who use all their resources to oppose Japanese aggression to the end.',
#   'languages': ['English'],
#   'released': datetime.datetime(2005, 4, 6, 0, 0),
#   'directors': ['Frank Capra', 'Anatole Litvak'],
#   'writers': ['Julius J. Epstein', 'Philip G. Epstein'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-08-22 00:59:59.873000000',
#   'year': 1944,
#   'imdb': {'rating': 7.3, 'votes': 407, 'id': 184254},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1},
#    'lastUpdated': datetime.datetime(2015, 8, 8, 18, 57, 46)}},
#  {'_id': ObjectId('573a139ff29313caabcfff82'),
#   'plot': 'The official World War II US government account of Nazi international aggression leading up to the British and French declarations of war.',
#   'genres': ['Documentary', 'Short', 'War'],
#   'runtime': 41,
#   'title': 'The Nazis Strike',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTM0MjQ1MDk0MV5BMl5BanBnXkFtZTcwNzkwMDYxMQ@@._V1_SY1000_SX677_AL_.jpg',
#   'countries': ['USA'],
#   'fullplot': "In this installment of the Why We Fight propaganda film series, we see the events of Nazi Germany's diplomatic and military acts of international aggression. One by one, we learn of the Nazi's consistently underhanded and relenting violation of every promise of peace and exploitation of their foes's attempts of appeasement until the invasion of Poland September of 1939 which led to Britain and France finally taking an armed stand against Hitler.",
#   'languages': ['English'],
#   'cast': ['Eduard Benes',
#    'Neville Chamberlain',
#    'Clementine Churchill',
#    'Winston Churchill'],
#   'directors': ['Frank Capra', 'Anatole Litvak'],
#   'writers': ['Julius J. Epstein', 'Philip G. Epstein', 'Adolf Hitler (book)'],
#   'awards': {'wins': 2, 'nominations': 0, 'text': '2 wins.'},
#   'lastupdated': '2015-08-23 00:19:55.123000000',
#   'year': 1943,
#   'imdb': {'rating': 7.3, 'votes': 523, 'id': 184773},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 7},
#    'dvd': datetime.datetime(1999, 12, 7, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 7, 16, 18, 45, 2)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a13b2f29313caabd38c8d'),
#   'plot': 'Emi Ota and her friend Okiku stay briefly at a mountain inn and then return to Tokyo. Later, Nanmura, a soldier on leave, steps on an ornamental hairpin in the public bath at the inn. Emi ...',
#   'genres': ['Drama'],
#   'runtime': 70,
#   'cast': ["Shin'ichi Himori",
#    'Kanji Kawahara',
#    'Hiroko Kawasaki',
#    'Koji Matsumoto'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZTAyYjc3ZGEtNTkzZi00Y2I1LWE3ZDEtYWI1MmYyOTFmY2UwXkEyXkFqcGdeQXVyMzY2MDk0MTk@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Ornamental Hairpin',
#   'fullplot': 'Emi Ota and her friend Okiku stay briefly at a mountain inn and then return to Tokyo. Later, Nanmura, a soldier on leave, steps on an ornamental hairpin in the public bath at the inn. Emi writes to the inn saying she has lost a hairpin and, when she discovers that it injured Nanmura, returns to apologize. The longer term visitors at the inn meet together to discuss the hairpin incident. These include a grumpy Professor, a young couple Mr and Mrs Hiroyasu, and an old man staying with his two grandsons. They hope to see a romance blossom between Nanmura and Emi, after Nanmura declares that there is something almost poetic in finding a hairpin in the bath.',
#   'languages': ['Japanese'],
#   'released': datetime.datetime(1941, 8, 26, 0, 0),
#   'directors': ['Hiroshi Shimizu'],
#   'writers': ['Masuji Ibuse (story)', 'Yoshitomo Nagase'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-07-12 00:34:55.437000000',
#   'year': 1941,
#   'imdb': {'rating': 7.3, 'votes': 335, 'id': 427424},
#   'countries': ['Japan'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 80, 'meter': 84},
#    'dvd': datetime.datetime(2009, 3, 17, 0, 0),
#    'critic': {'numReviews': 1},
#    'lastUpdated': datetime.datetime(2015, 1, 7, 2, 25),
#    'rotten': 0,
#    'production': 'Criterion Collection',
#    'fresh': 1}}]

# %% [markdown]
# #### Задача 1.5 — **1 балл**

# %% [markdown]
# Модифицируйте запрос из задачи 1.4 таким образом, чтобы осуществить _проекцию_: результатом выборки должен стать список словарей, каждый из которых содержит только два поля: `title` и `year`.
#
# Для справки о проекции см. документацию по методу `find()` в pymongo:
# https://pymongo.readthedocs.io/en/stable/api/pymongo/collection.html#pymongo.collection.Collection.find

# %%
# Ваш код здесь
filter = {
    '$or': [
        {
            'genres': 'Film-Noir'
        }, {
            'genres': 'Horror'
        }, {
            'year': {
                '$gt': 1939
            }
        }
    ], 
    'year': {
        '$lt': 1950
    }
}
projection = ["title", "year"]
list(movies.find(filter=filter, projection=projection))
# Out:
# [{'_id': ObjectId('573a1391f29313caabcd935e'),
#   'title': 'Little Caesar',
#   'year': 1931},
#  {'_id': ObjectId('573a1391f29313caabcd9637'),
#   'title': 'Dracula',
#   'year': 1931},
#  {'_id': ObjectId('573a1392f29313caabcd9a3b'),
#   'title': 'Dr. Jekyll and Mr. Hyde',
#   'year': 1931},
#  {'_id': ObjectId('573a1392f29313caabcda241'),
#   'title': 'The Black Cat',
#   'year': 1934},
#  {'_id': ObjectId('573a1392f29313caabcda482'),
#   'title': 'The Man Who Knew Too Much',
#   'year': 1934},
#  {'_id': ObjectId('573a1392f29313caabcda826'),
#   'title': 'The Ghost Goes West',
#   'year': 1935},
#  {'_id': ObjectId('573a1392f29313caabcdabdd'),
#   'title': 'Black Legion',
#   'year': 1937},
#  {'_id': ObjectId('573a1392f29313caabcdad95'),
#   'title': 'The Invisible Ray',
#   'year': 1936},
#  {'_id': ObjectId('573a1392f29313caabcdb314'),
#   'title': 'Marked Woman',
#   'year': 1937},
#  {'_id': ObjectId('573a1392f29313caabcdb4d5'),
#   'title': "They Won't Forget",
#   'year': 1937},
#  {'_id': ObjectId('573a1392f29313caabcdb5a9'),
#   'title': 'Angels with Dirty Faces',
#   'year': 1938},
#  {'_id': ObjectId('573a1392f29313caabcdbdd3'),
#   'title': 'The Stars Look Down',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdbeca'),
#   'title': 'The Siege of the Alcazar',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdbed0'),
#   'title': 'Arise, My Love',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdbed5'),
#   'title': 'The Bank Dick',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdbef1'),
#   'title': 'The Biscuit Eater',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdbef6'),
#   'title': 'Black Friday',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdbf6c'),
#   'title': 'Dance, Girl, Dance',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdbf81'), 'title': 'Dots', 'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdbf82'),
#   'title': 'Down Argentine Way',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdbfb0'),
#   'title': 'Fantasia',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc030'),
#   'title': 'The Great Dictator',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc04b'),
#   'title': 'His Girl Friday',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc076'),
#   'title': 'Jud Sèè',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc093'),
#   'title': 'Kitty Foyle',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc0a0'),
#   'title': 'Knute Rockne All American',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc0bb'),
#   'title': 'The Letter',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc0cb'),
#   'title': 'The Long Voyage Home',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc0f7'),
#   'title': 'The Mark of Zorro',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc150'),
#   'title': 'North West Mounted Police',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc180'),
#   'title': 'Pinocchio',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc207'),
#   'title': 'The Shop Around the Corner',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc23e'),
#   'title': 'Strike Up the Band',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc2e2'),
#   'title': 'The Westerner',
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc364'),
#   'title': 'Blood and Sand',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc370'),
#   'title': 'The Blood of Jesus',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc371'),
#   'title': 'Blossoms in the Dust',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc3a3'),
#   'title': 'Citizen Kane',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc3f7'),
#   'title': 'The Devil and Daniel Webster',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc403'), 'title': 'Dumbo', 'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc435'),
#   'title': "The Well-Digger's Daughter",
#   'year': 1940},
#  {'_id': ObjectId('573a1393f29313caabcdc4a2'),
#   'title': 'Here Comes Mr. Jordan',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc4a8'),
#   'title': 'High Sierra',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc4b3'),
#   'title': 'How Green Was My Valley',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc50e'),
#   'title': 'The Land',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc514'),
#   'title': 'The Little Foxes',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc539'),
#   'title': 'Love on the Dole',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc544'),
#   'title': 'Major Barbara',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc558'),
#   'title': 'The Man Who Came to Dinner',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc57c'),
#   'title': 'The White Ship',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc5dc'),
#   'title': "'Pimpernel' Smith",
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc62b'),
#   'title': 'Road to Zanzibar',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc664'),
#   'title': 'The Sea Wolf',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc672'),
#   'title': 'Sergeant York',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc6af'),
#   'title': 'They Met in Moscow',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc6c6'),
#   'title': 'That Hamilton Woman',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc6e9'),
#   'title': 'Tom Dick and Harry',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc6f0'),
#   'title': 'The Brothers and Sisters of the Toda Family',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc706'),
#   'title': 'Two-Faced Woman',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc742'),
#   'title': 'The Wolf Man',
#   'year': 1941},
#  {'_id': ObjectId('573a1393f29313caabcdc77e'),
#   'title': 'Across the Pacific',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc7aa'), 'title': 'Bambi', 'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc7c9'),
#   'title': 'The Black Swan',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc810'),
#   'title': 'Casablanca',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc814'),
#   'title': 'Cat People',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc87b'),
#   'title': 'People on the Alps',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc8e2'),
#   'title': 'Der groèe Kènig',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc8f0'),
#   'title': 'The Hard Way',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdc91c'),
#   'title': 'Holiday Inn',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc953'),
#   'title': 'Jungle Book',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc958'),
#   'title': 'Journey for Margaret',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc9ab'),
#   'title': 'The Magnificent Ambersons',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc9ba'),
#   'title': 'The Male Animal',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc9ce'),
#   'title': 'The Major and the Minor',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdc9f5'),
#   'title': 'The Moon and Sixpence',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdca03'),
#   'title': 'Mrs. Miniver',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdca18'),
#   'title': 'My Gal Sal',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdca3b'),
#   'title': 'Ossessione',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdca3f'),
#   'title': 'One of Our Aircraft Is Missing',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdca58'),
#   'title': 'The Pied Piper',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdca76'),
#   'title': 'Prelude to War',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdca79'),
#   'title': 'The Pride of the Yankees',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdca8a'),
#   'title': 'Random Harvest',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdcab3'),
#   'title': 'Saboteur',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdcb60'),
#   'title': 'This Above All',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdcb64'),
#   'title': 'To Be or Not to Be',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdcbc9'),
#   'title': 'Wake Island',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdcbdd'),
#   'title': 'Woman of the Year',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdcbfb'),
#   'title': 'Yankee Doodle Dandy',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdcc03'),
#   'title': 'Air Force',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcc33'),
#   'title': 'Bataan',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcc5c'),
#   'title': 'Cabin in the Sky',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdccb6'),
#   'title': 'Desert Victory',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcd39'),
#   'title': "The Gang's All Here",
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcd4e'),
#   'title': 'The Ghost Ship',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcd6b'),
#   'title': 'Hangmen Also Die!',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcd7b'),
#   'title': 'Hello Frisco, Hello',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcd9d'),
#   'title': 'I Walked with a Zombie',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcda1'),
#   'title': 'Holy Matrimony',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcde5'),
#   'title': 'Lassie Come Home',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcdf2'),
#   'title': 'The Life and Death of Colonel Blimp',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcdf5'),
#   'title': 'The Leopard Man',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdce1b'),
#   'title': 'Meshes of the Afternoon',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdce23'),
#   'title': 'The Memphis Belle: A Story of a Flying Fortress',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdce39'),
#   'title': 'The More the Merrier',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdce88'),
#   'title': 'Phantom of the Opera',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdceb0'),
#   'title': 'Report from the Aleutians',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdced3'),
#   'title': 'Saludos Amigos',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdceee'),
#   'title': 'The Seventh Victim',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcef2'),
#   'title': 'Shadow of a Doubt',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcef3'),
#   'title': 'So Proudly We Hail!',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcf0e'),
#   'title': 'The Song of Bernadette',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcf14'),
#   'title': 'Stormy Weather',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcf2f'),
#   'title': 'This Is the Army',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcf71'),
#   'title': 'Victory Through Air Power',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcf84'),
#   'title': 'Watch on the Rhine',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdcff5'),
#   'title': 'The Battle of Russia',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdd05d'),
#   'title': 'The Curse of the Cat People',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd0ae'),
#   'title': 'Double Indemnity',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd0b6'),
#   'title': 'The Fighting Lady',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd0e5'),
#   'title': 'The Best Years of Our Lives',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd0eb'),
#   'title': 'Gaslight',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd0f1'),
#   'title': 'Going My Way',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd0fa'),
#   'title': 'Hail the Conquering Hero',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd11e'),
#   'title': 'Torment',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd170'), 'title': 'Laura', 'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd179'),
#   'title': 'Lifeboat',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd1a3'),
#   'title': 'Meet Me in St. Louis',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd1a8'),
#   'title': 'Marèa Candelaria (Xochimilco)',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd1ec'),
#   'title': 'Murder, My Sweet',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd1f1'),
#   'title': 'None But the Lonely Heart',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd1f5'),
#   'title': 'National Velvet',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd2a7'),
#   'title': 'Since You Went Away',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd2e1'),
#   'title': 'This Happy Breed',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd2eb'),
#   'title': 'Thirty Seconds Over Tokyo',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd31c'),
#   'title': 'Tunisian Victory',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd329'),
#   'title': 'The Way Ahead',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd374'),
#   'title': 'And Then There Were None',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd38c'),
#   'title': 'The Body Snatcher',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd3ce'),
#   'title': 'The Clock',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd3e5'),
#   'title': 'Detour',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd3ed'),
#   'title': 'Dead of Night',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd3f3'),
#   'title': 'Domingo de carnaval',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd40f'),
#   'title': "L'espoir",
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd414'),
#   'title': 'Children of Paradise',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd481'),
#   'title': 'House of Dracula',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd482'),
#   'title': 'The House on 92nd Street',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd49b'),
#   'title': 'Isle of the Dead',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd4c8'),
#   'title': 'Leave Her to Heaven',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd4ee'),
#   'title': 'The Last Chance',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd551'),
#   'title': 'La perla',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcdd574'),
#   'title': 'Rhapsody in Blue',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd57b'),
#   'title': 'Red Meadows',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd5ba'),
#   'title': 'The Southerner',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd5c7'),
#   'title': 'Story of G.I. Joe',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd5cc'),
#   'title': 'A Song to Remember',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd5cd'),
#   'title': 'State Fair',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd5e9'),
#   'title': 'The Testimony',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd60a'),
#   'title': 'The Three Caballeros',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcdd622'),
#   'title': 'A Tree Grows in Brooklyn',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd62e'),
#   'title': 'The Valley of Decision',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd652'),
#   'title': 'Wonder Man',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd659'),
#   'title': 'A Walk in the Sun',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd679'),
#   'title': 'I See a Dark Stranger',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd688'),
#   'title': 'Anna and the King of Siam',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd69c'),
#   'title': 'The Battle of the Rails',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd69f'),
#   'title': 'The Bandit',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd6b0'),
#   'title': 'Bedlam',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd6b2'),
#   'title': 'The Big Sleep',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd6b8'),
#   'title': 'The Best Years of Our Lives',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd6df'),
#   'title': 'Caesar and Cleopatra',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd6e5'),
#   'title': 'The Captive Heart',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd6e7'),
#   'title': 'The Chase',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd72b'),
#   'title': 'Devil in the Flesh',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcdd72d'),
#   'title': 'The Diary of a Chambermaid',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd74c'),
#   'title': 'Enamorada',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd7d8'),
#   'title': "It's a Wonderful Life",
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd7ed'),
#   'title': 'The Jolson Story',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd807'),
#   'title': 'Let There Be Light',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd808'),
#   'title': 'Levoton veri',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd831'),
#   'title': 'Make Mine Music',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd840'),
#   'title': 'Stairway to Heaven',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd852'),
#   'title': 'My Darling Clementine',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd859'),
#   'title': 'Murderers Among Us',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd85b'),
#   'title': 'Muzi bez krèdel',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd86b'),
#   'title': 'Notorious',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd89b'), 'title': 'Panic', 'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd8ad'),
#   'title': 'La porta del cielo',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd8b6'),
#   'title': "The Razor's Edge",
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd8c7'),
#   'title': 'Rome, Open City',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd8f4'),
#   'title': 'The Seventh Veil',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd901'),
#   'title': 'Sister Kenny',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd916'),
#   'title': 'Song of the South',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd937'),
#   'title': 'The Stranger',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd943'),
#   'title': 'Pastoral Symphony',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd95d'),
#   'title': 'To Each His Own',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd9af'),
#   'title': 'The Yearling',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdd9b4'),
#   'title': 'Ziegfeld Follies',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd9c7'),
#   'title': 'The Eagle with Two Heads',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcdd9da'),
#   'title': 'The Ball at the Anjo House',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcdda01'),
#   'title': 'Body and Soul',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcdda05'),
#   'title': 'Boomerang!',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcdda18'),
#   'title': 'Bowery Buckaroos',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcdda52'),
#   'title': 'The Cat Concerto',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcdda94'),
#   'title': 'Dreams That Money Can Buy',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcdda98'),
#   'title': "Dèdèe d'Anvers",
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcdda9a'),
#   'title': 'A Double Life',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddad5'),
#   'title': "Gentleman's Agreement",
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddaf1'),
#   'title': 'The Fugitive',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddaf2'),
#   'title': 'Lost Youth',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddaf5'),
#   'title': 'Green Dolphin Street',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddb29'),
#   'title': 'Hungry Hill',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddb2b'),
#   'title': 'It Happened on Fifth Avenue',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddb58'),
#   'title': 'Kiss of Death',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddba7'),
#   'title': 'The Damned',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddba9'),
#   'title': 'Mine Own Executioner',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddbb0'),
#   'title': 'Mother Wore Tights',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddbb5'),
#   'title': 'Miracle on 34th Street',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddbb8'),
#   'title': 'Monsieur Vincent',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddbbc'),
#   'title': 'Mourning Becomes Electra',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddbed'),
#   'title': 'La nao capitana',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddc0a'),
#   'title': 'Possessed',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddc2b'),
#   'title': 'Angelina',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddc39'),
#   'title': 'Quai des Orfèvres',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddc76'),
#   'title': 'Symphony of Life',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddc78'),
#   'title': 'The Sin of Harold Diddlebock',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddca8'),
#   'title': 'One Wonderful Sunday',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddcb5'),
#   'title': 'I Became a Criminal',
#   'year': 1947},
#  {'_id': ObjectId('573a1393f29313caabcddcc1'),
#   'title': 'Torment',
#   'year': 1944},
#  {'_id': ObjectId('573a1393f29313caabcddd6d'),
#   'title': 'An Act of Murder',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddd7a'),
#   'title': "L'amore",
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddd7d'),
#   'title': 'All My Sons',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddd85'),
#   'title': 'Bud Abbott Lou Costello Meet Frankenstein',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddd8a'),
#   'title': "Angels' Alley",
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddd8f'),
#   'title': 'Apartment for Peggy',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddd97'),
#   'title': 'Anni difficili',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcdddb8'),
#   'title': 'Berlin Express',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcdddc7'),
#   'title': 'The Walls of Malapaga',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcdddc8'),
#   'title': 'The Big Clock',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddde7'),
#   'title': 'Call Northside 777',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcdde0f'),
#   'title': 'Command Decision',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcdde29'),
#   'title': 'Cry of the City',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcdde51'),
#   'title': 'Easter Parade',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcdde5a'),
#   'title': 'The Emperor Waltz',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcdde6d'),
#   'title': 'Quartet',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcdde7c'),
#   'title': 'Every Girl Should Be Married',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcdde8b'),
#   'title': 'Force of Evil',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcdde97'),
#   'title': 'A Foreign Affair',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddea3'),
#   'title': 'Fort Apache',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcdded2'),
#   'title': 'He Walked by Night',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddef2'),
#   'title': 'I Remember Mama',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddf1b'),
#   'title': 'June Bride',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddf2b'),
#   'title': 'A Hen in the Wind',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddf4d'),
#   'title': 'Louisiana Story',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddf56'),
#   'title': 'Macbeth',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddf5e'),
#   'title': 'The Mating of Millie',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddf75'),
#   'title': 'La mies es mucha',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddf76'),
#   'title': 'Melody Time',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddf82'),
#   'title': 'Mr. Blandings Builds His Dream House',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddf88'),
#   'title': 'The Mill on the Po',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcddfa4'),
#   'title': 'The Naked City',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddfcf'),
#   'title': 'The Paleface',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddfd3'),
#   'title': 'The Pirate',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddff1'),
#   'title': 'Red River',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddff4'),
#   'title': 'Portrait of Jennie',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcddfff'),
#   'title': 'Bitter Rice',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde008'), 'title': 'Rope', 'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde00c'),
#   'title': 'Road House',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde01b'),
#   'title': 'Salèn Mèxico',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde022'),
#   'title': 'Without Pity',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde024'),
#   'title': 'The Search',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde043'),
#   'title': 'Sitting Pretty',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde04e'),
#   'title': 'The Snake Pit',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde05f'),
#   'title': 'Sorry, Wrong Number',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde061'),
#   'title': 'Station West',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde07e'),
#   'title': 'The Street with No Name',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde083'),
#   'title': 'That Lady in Ermine',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde089'),
#   'title': 'La Terra Trema',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde0a0'),
#   'title': 'To the Ends of the Earth',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde0e7'),
#   'title': 'The Winslow Boy',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde0f0'),
#   'title': 'Yellow Sky',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde0fe'),
#   'title': 'You Were Meant for Me',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde107'),
#   'title': 'Yoru no onnatachi',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde160'),
#   'title': "Adam's Rib",
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde169'),
#   'title': 'Act of Violence',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde178'),
#   'title': "All the King's Men",
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde1ae'),
#   'title': 'Begone Dull Care',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde1af'),
#   'title': 'The Barkleys of Broadway',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde1ce'),
#   'title': 'The Blue Lagoon',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde1dd'),
#   'title': 'Battleground',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde1f8'),
#   'title': 'Chicago Deadline',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde1fe'),
#   'title': 'Champion',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde207'),
#   'title': 'Come to the Stable',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde264'),
#   'title': 'Edward, My Son',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde2c4'),
#   'title': 'Give Us This Day',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde2c8'),
#   'title': 'The Heiress',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde2d7'),
#   'title': 'The Hasty Heart',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde2db'),
#   'title': 'The Hidden Room',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde2f7'),
#   'title': 'House of Strangers',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde2fc'),
#   'title': 'Home of the Brave',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde2ff'),
#   'title': 'In the Good Old Summertime',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde300'),
#   'title': 'I Was a Male War Bride',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde305'),
#   'title': 'Intruder in the Dust',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde309'),
#   'title': 'In the Name of the Law',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde316'),
#   'title': 'Jolson Sings Again',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde326'),
#   'title': 'It Happens Every Spring',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde361'),
#   'title': 'Little Women',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde367'),
#   'title': 'Lost Boundaries',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde36c'),
#   'title': 'Madame Bovary',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde37e'), 'title': 'Manon', 'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde3af'),
#   'title': 'Mighty Joe Young',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde3be'),
#   'title': "Neptune's Daughter",
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde3ca'),
#   'title': "Occupe-toi d'Amèlie..!",
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde3e5'),
#   'title': 'On the Town',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde3ee'),
#   'title': 'The Passionate Friends',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde3ef'),
#   'title': 'Passport to Pimlico',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde3fa'), 'title': 'Pinky', 'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde40d'),
#   'title': 'Prince of Foxes',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde417'),
#   'title': 'The Queen of Spades',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde420'),
#   'title': 'Quartet',
#   'year': 1948},
#  {'_id': ObjectId('573a1393f29313caabcde453'),
#   'title': 'Scene of the Crime',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde458'),
#   'title': 'Sands of Iwo Jima',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde460'),
#   'title': 'The Set-Up',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde47a'),
#   'title': 'The Quiet Duel',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde4a8'),
#   'title': 'The Stratton Story',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde4b4'),
#   'title': 'Take Me Out to the Ball Game',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde4be'),
#   'title': 'That Forsyte Woman',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde4f6'),
#   'title': 'Under Capricorn',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde515'),
#   'title': 'Whisky Galore',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde52f'),
#   'title': 'The Window',
#   'year': 1949},
#  {'_id': ObjectId('573a1393f29313caabcde53f'),
#   'title': 'Wuya yu maque',
#   'year': 1949},
#  {'_id': ObjectId('573a1397f29313caabce7f5a'),
#   'title': 'Let There Be Light',
#   'year': 1946},
#  {'_id': ObjectId('573a139af29313caabcf11e8'),
#   'title': 'Sleeping Beauty',
#   'year': 1949},
#  {'_id': ObjectId('573a139bf29313caabcf3d6d'),
#   'title': 'Rosvo Roope',
#   'year': 1949},
#  {'_id': ObjectId('573a139cf29313caabcf56c0'),
#   'title': 'Make Mine Music',
#   'year': 1946},
#  {'_id': ObjectId('573a139df29313caabcf8f76'),
#   'title': 'Neecha Nagar',
#   'year': 1946},
#  {'_id': ObjectId('573a139df29313caabcfa6cd'),
#   'title': 'èA volar joven!',
#   'year': 1947},
#  {'_id': ObjectId('573a139ef29313caabcfd5ef'),
#   'title': 'Divide and Conquer',
#   'year': 1943},
#  {'_id': ObjectId('573a139ff29313caabcff7d1'),
#   'title': 'The Battle of Britain',
#   'year': 1943},
#  {'_id': ObjectId('573a139ff29313caabcff8ae'),
#   'title': 'Divide and Conquer',
#   'year': 1943},
#  {'_id': ObjectId('573a139ff29313caabcffc7d'),
#   'title': 'War Comes to America',
#   'year': 1945},
#  {'_id': ObjectId('573a139ff29313caabcffd74'),
#   'title': 'The Battle of China',
#   'year': 1944},
#  {'_id': ObjectId('573a139ff29313caabcfff82'),
#   'title': 'The Nazis Strike',
#   'year': 1943},
#  {'_id': ObjectId('573a13b2f29313caabd38c8d'),
#   'title': 'Ornamental Hairpin',
#   'year': 1941}]

# %% [markdown]
# ### Упражнение 2. Конвейер агрегации

# %% [markdown]
# #### Задача 2.1 — **3 балла**

# %% [markdown]
# В рамках этой задачи требуется узнать, какие фильмы получили наибольшее число комментариев. Составьте для этого конвейер агрегации с перечисленными ниже этапами. Для удобства рекомендуется воспользоваться приложением Compass.
#
# 1. Сгруппировать документы коллекции `comments` по полю `movie_id` и подсчитать количество комментариев для каждого фильма, записав его в поле `count`.
# 1. Отсортировать получившийся набор данных по убыванию количества комментариев (так чтобы первый документ в этом наборе указывал на фильм с наибольшим количеством комментариев).
# 1. Используя оператор `$lookup`, присоединить коллекцию `movies` (по полю `movie_id`).
# 1. Выполнить проекцию, оставив в наборе данных только три поля: название фильма (`title`), год выпуска (`year`) и количество комментариев (поле `count`, добавленное на первом этапе). Для этого воспользуйтесь оператором `$project`: https://www.mongodb.com/docs/manual/reference/operator/aggregation/project/. Обратите внимание, что данные из коллекции `movies` (`title` и `year`) на этом этапе окажутся внутри массива.
# 1. Применить оператор `$unwind`, чтобы деконструировать этот массив. См. https://www.mongodb.com/docs/manual/reference/operator/aggregation/unwind/. В результате массив должен превратиться в одиночный объект.
# 1. Применить оператор `$addFields`, чтобы добавить поля `title` и `year` на вернхий уровень структуры документа. См. https://www.mongodb.com/docs/manual/reference/operator/aggregation/addFields/.
# 1. Еще раз выполнить проекцию, чтобы удалить поле с массивом.
#
# Ваш алгоритм решения может отличаться от приведенного здесь. Главное — достичь цели: получить плоский набор данных с тремя полями (`count` — количество комментариев, `year` — год выпуска, `title` — название фильма).
#
# Скопируйте полученный конвейер в этот документ в виде кода на Python и выведите его на экран в виде списка словарей.

# %%
movie_comments = client['sample_mflix']['comments'].aggregate([
    {
        '$group': {
            '_id': '$movie_id', 
            'count': {
                '$sum': 1
            }
        }
    }, {
        '$sort': {
            'count': -1
        }
    }, {
        '$lookup': {
            'as': 'movies', 
            'from': 'movies', 
            'foreignField': '_id', 
            'localField': '_id'
        }
    }, {
        '$project': {
            'movies.title': 1, 
            'movies.year': 1, 
            'count': 1
        }
    }, {
        '$unwind': {
            'path': '$movies'
        }
    }, {
        '$addFields': {
            'year': '$movies.year', 
            'title': '$movies.title'
        }
    }, {
        '$project': {
            'count': 1, 
            'title': 1, 
            'year': 1,
            "_id": 0
        }
    }
])

movie_comments = list(movie_comments)
movie_comments
# Out:
# [{'count': 161, 'year': 2009, 'title': 'The Taking of Pelham 1 2 3'},
#  {'count': 158, 'year': 2009, 'title': 'Terminator Salvation'},
#  {'count': 158, 'year': 2004, 'title': '50 First Dates'},
#  {'count': 158, 'year': 2002, 'title': 'About a Boy'},
#  {'count': 158, 'year': 2001, 'title': "Ocean's Eleven"},
#  {'count': 157, 'year': 1999, 'title': 'The Mummy'},
#  {'count': 157, 'year': 2009, 'title': 'Sherlock Holmes'},
#  {'count': 155, 'year': 2008, 'title': 'Hellboy II: The Golden Army'},
#  {'count': 154, 'year': 2001, 'title': 'The Mummy Returns'},
#  {'count': 154,
#   'year': 2004,
#   'title': 'Anchorman: The Legend of Ron Burgundy'},
#  {'count': 153, 'year': 1999, 'title': 'American Pie'},
#  {'count': 153, 'year': 1982, 'title': 'E.T. the Extra-Terrestrial'},
#  {'count': 153, 'year': 1996, 'title': 'Mission: Impossible'},
#  {'count': 153, 'year': 1950, 'title': 'Cinderella'},
#  {'count': 153, 'year': 2003, 'title': 'Bruce Almighty'},
#  {'count': 153,
#   'year': 2007,
#   'title': "Pirates of the Caribbean: At World's End"},
#  {'count': 153, 'year': 2000, 'title': 'X-Men'},
#  {'count': 153, 'year': 2008, 'title': 'Wanted'},
#  {'count': 152, 'year': 2000, 'title': 'Gladiator'},
#  {'count': 152, 'year': 2002, 'title': 'The Ring'},
#  {'count': 151, 'year': 2003, 'title': 'The Matrix Reloaded'},
#  {'count': 151, 'year': 2004, 'title': 'Meet the Fockers'},
#  {'count': 151, 'year': 1994, 'title': 'The Mask'},
#  {'count': 150, 'year': 1999, 'title': 'Big Daddy'},
#  {'count': 150, 'year': 1999, 'title': 'Toy Story 2'},
#  {'count': 148, 'year': 1995, 'title': 'Braveheart'},
#  {'count': 148, 'year': 1993, 'title': 'Jurassic Park'},
#  {'count': 148, 'year': 2007, 'title': 'I Am Legend'},
#  {'count': 147, 'year': 2008, 'title': 'The Express'},
#  {'count': 147, 'year': 2000, 'title': 'Scary Movie'},
#  {'count': 147, 'year': 1975, 'title': 'Jaws'},
#  {'count': 146, 'year': 1996, 'title': 'Twister'},
#  {'count': 146, 'year': 2007, 'title': 'I Now Pronounce You Chuck & Larry'},
#  {'count': 145, 'year': 2000, 'title': 'Cast Away'},
#  {'count': 145, 'year': 1994, 'title': 'Dumb & Dumber'},
#  {'count': 145, 'year': 2006, 'title': '300'},
#  {'count': 144, 'year': 2007, 'title': 'Spider-Man 3'},
#  {'count': 144, 'year': 1998, 'title': 'Saving Private Ryan'},
#  {'count': 144, 'year': 1982, 'title': 'Dègkeselyè'},
#  {'count': 144, 'year': 2007, 'title': 'Hostel: Part II'},
#  {'count': 144, 'year': 2009, 'title': 'I Love You, Man'},
#  {'count': 144, 'year': 2009, 'title': 'The Hangover'},
#  {'count': 144, 'year': 2007, 'title': 'The Simpsons Movie'},
#  {'count': 144, 'year': 1999, 'title': 'The Green Mile'},
#  {'count': 144, 'year': 2009, 'title': 'The Last House on the Left'},
#  {'count': 144, 'year': 1992, 'title': 'Aladdin'},
#  {'count': 144, 'year': 2001, 'title': 'Zoolander'},
#  {'count': 144, 'year': 2005, 'title': 'King Kong'},
#  {'count': 144, 'year': 2003, 'title': 'School of Rock'},
#  {'count': 143, 'year': 2002, 'title': '8 Mile'},
#  {'count': 143, 'year': 2009, 'title': 'Up'},
#  {'count': 143, 'year': 2002, 'title': 'Ice Age'},
#  {'count': 143,
#   'year': 2002,
#   'title': 'Harry Potter and the Chamber of Secrets'},
#  {'count': 143, 'year': 2001, 'title': 'Rush Hour 2'},
#  {'count': 143, 'year': 1993, 'title': 'The Jungle Creature: Hugo'},
#  {'count': 143, 'year': 2003, 'title': 'Kill Bill: Vol. 1'},
#  {'count': 142, 'year': 1994, 'title': 'Speed'},
#  {'count': 142, 'year': 2009, 'title': 'Star Trek'},
#  {'count': 142, 'year': 2004, 'title': "Ocean's Twelve"},
#  {'count': 142, 'year': 2010, 'title': 'Shutter Island'},
#  {'count': 142, 'year': 1989, 'title': 'Back to the Future Part II'},
#  {'count': 141, 'year': 1995, 'title': 'Billy Madison'},
#  {'count': 141, 'year': 2007, 'title': 'Live Free or Die Hard'},
#  {'count': 141, 'year': 2007, 'title': '1408'},
#  {'count': 141, 'year': 1998, 'title': 'Rush Hour'},
#  {'count': 141, 'year': 2003, 'title': 'Freaky Friday'},
#  {'count': 141, 'year': 2001, 'title': 'The Princess Diaries'},
#  {'count': 141, 'year': 2007, 'title': 'Evan Almighty'},
#  {'count': 140, 'year': 2005, 'title': 'Mr. & Mrs. Smith'},
#  {'count': 140, 'year': 2003, 'title': 'X-Men 2'},
#  {'count': 140, 'year': 2003, 'title': 'Cheaper by the Dozen'},
#  {'count': 140, 'year': 2002, 'title': 'Men in Black II'},
#  {'count': 140, 'year': 1990, 'title': 'Back to the Future Part III'},
#  {'count': 140, 'year': 2007, 'title': 'Ghost Rider'},
#  {'count': 140, 'year': 2007, 'title': 'The Bourne Ultimatum'},
#  {'count': 140, 'year': 2005, 'title': 'War of the Worlds'},
#  {'count': 139, 'year': 2003, 'title': 'The Matrix Revolutions'},
#  {'count': 139, 'year': 2005, 'title': 'V for Vendetta'},
#  {'count': 139, 'year': 1996, 'title': 'Happy Gilmore'},
#  {'count': 139, 'year': 1939, 'title': 'The Wizard of Oz'},
#  {'count': 139, 'year': 1995, 'title': 'Ace Ventura: When Nature Calls'},
#  {'count': 139, 'year': 1997, 'title': 'Liar Liar'},
#  {'count': 139, 'year': 2009, 'title': 'Saw VI'},
#  {'count': 138, 'year': 2004, 'title': 'Shark Tale'},
#  {'count': 138, 'year': 2001, 'title': 'Donnie Darko'},
#  {'count': 138, 'year': 2000, 'title': 'Gone in Sixty Seconds'},
#  {'count': 138,
#   'year': 2007,
#   'title': 'Sweeney Todd: The Demon Barber of Fleet Street'},
#  {'count': 138, 'year': 2003, 'title': 'How to Lose a Guy in 10 Days'},
#  {'count': 138,
#   'year': 2001,
#   'title': "Harry Potter and the Sorcerer's Stone"},
#  {'count': 138, 'year': 2009, 'title': 'A Christmas Carol'},
#  {'count': 138, 'year': 2012, 'title': 'Men in Black 3'},
#  {'count': 138, 'year': 2000, 'title': 'How the Grinch Stole Christmas'},
#  {'count': 138, 'year': 1999, 'title': 'The Matrix'},
#  {'count': 137,
#   'year': 2005,
#   'title': 'Star Wars: Episode III - Revenge of the Sith'},
#  {'count': 137, 'year': 1996, 'title': 'Independence Day'},
#  {'count': 137, 'year': 2005, 'title': 'The 40-Year-Old Virgin'},
#  {'count': 137, 'year': 1999, 'title': 'Fight Club'},
#  {'count': 137, 'year': 2002, 'title': 'My Big Fat Greek Wedding'},
#  {'count': 137, 'year': 2003, 'title': 'Elf'},
#  {'count': 136,
#   'year': 2004,
#   'title': 'Harry Potter and the Prisoner of Azkaban'},
#  {'count': 136, 'year': 1998, 'title': 'The Waterboy'},
#  {'count': 136, 'year': 2008, 'title': 'The Dark Knight'},
#  {'count': 136, 'year': 1976, 'title': 'Rocky'},
#  {'count': 136, 'year': 1988, 'title': 'Beetlejuice'},
#  {'count': 136, 'year': 2000, 'title': 'Cast Away'},
#  {'count': 136, 'year': 1993, 'title': 'The Nightmare Before Christmas'},
#  {'count': 136, 'year': 2002, 'title': 'The Bourne Identity'},
#  {'count': 136, 'year': 1994, 'title': 'Forrest Gump'},
#  {'count': 135, 'year': 2000, 'title': 'Bring It On'},
#  {'count': 135, 'year': 2009, 'title': 'Push'},
#  {'count': 135,
#   'year': 2005,
#   'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe'},
#  {'count': 135, 'year': 1989, 'title': 'Honey, I Shrunk the Kids'},
#  {'count': 135, 'year': 2002, 'title': 'Signs'},
#  {'count': 135, 'year': 1989, 'title': 'Indiana Jones and the Last Crusade'},
#  {'count': 134, 'year': 2005, 'title': 'Fantastic Four'},
#  {'count': 134, 'year': 1991, 'title': 'Beauty and the Beast'},
#  {'count': 134,
#   'year': 2007,
#   'title': 'Fantastic 4: Rise of the Silver Surfer'},
#  {'count': 134, 'year': 2009, 'title': 'The Uninvited'},
#  {'count': 134, 'year': 2001, 'title': 'American Pie 2'},
#  {'count': 134, 'year': 2001, 'title': 'Monsters, Inc.'},
#  {'count': 134, 'year': 1967, 'title': 'The Jungle Book'},
#  {'count': 134, 'year': 1999, 'title': 'The Mummy'},
#  {'count': 134, 'year': 2005, 'title': 'Sin City'},
#  {'count': 134, 'year': 2009, 'title': 'Transformers: Revenge of the Fallen'},
#  {'count': 134, 'year': 2000, 'title': 'Miss Congeniality'},
#  {'count': 134, 'year': 2004, 'title': 'Spider-Man 2'},
#  {'count': 133, 'year': 2004, 'title': 'Shrek 2'},
#  {'count': 133, 'year': 2001, 'title': 'The Fast and the Furious'},
#  {'count': 133,
#   'year': 2003,
#   'title': 'The Lord of the Rings: The Return of the King'},
#  {'count': 133, 'year': 2009, 'title': 'The Ugly Truth'},
#  {'count': 133, 'year': 2007, 'title': 'Blades of Glory'},
#  {'count': 132, 'year': 1997, 'title': 'Men in Black'},
#  {'count': 132, 'year': 1993, 'title': 'Free Willy'},
#  {'count': 132, 'year': 2007, 'title': 'Shrek the Third'},
#  {'count': 132, 'year': 2003, 'title': '2 Fast 2 Furious'},
#  {'count': 132, 'year': 1994, 'title': 'The Lion King'},
#  {'count': 132, 'year': 2009, 'title': "The Time Traveler's Wife"},
#  {'count': 132, 'year': 2002, 'title': 'Catch Me If You Can'},
#  {'count': 132, 'year': 1994, 'title': 'Ace Ventura: Pet Detective'},
#  {'count': 131, 'year': 1999, 'title': 'The Sixth Sense'},
#  {'count': 131, 'year': 1972, 'title': 'The Godfather'},
#  {'count': 131, 'year': 1998, 'title': 'Doctor Dolittle'},
#  {'count': 131, 'year': 1995, 'title': 'Toy Story'},
#  {'count': 131, 'year': 2009, 'title': 'The Unborn'},
#  {'count': 131, 'year': 1977, 'title': 'Star Wars: Episode IV - A New Hope'},
#  {'count': 131, 'year': 2004, 'title': 'Shark Tale'},
#  {'count': 131, 'year': 1994, 'title': 'The Shawshank Redemption'},
#  {'count': 131, 'year': 2000, 'title': 'Meet the Parents'},
#  {'count': 131, 'year': 1999, 'title': 'American Beauty'},
#  {'count': 131, 'year': 2009, 'title': 'Drag Me to Hell'},
#  {'count': 131, 'year': 2001, 'title': 'Shrek'},
#  {'count': 130, 'year': 1990, 'title': 'Pretty Woman'},
#  {'count': 130, 'year': 2004, 'title': 'The Day After Tomorrow'},
#  {'count': 130, 'year': 2006, 'title': 'Ice Age: The Meltdown'},
#  {'count': 130, 'year': 1991, 'title': 'Hook'},
#  {'count': 130, 'year': 2009, 'title': 'G.I. Joe: The Rise of Cobra'},
#  {'count': 130, 'year': 1990, 'title': 'Home Alone'},
#  {'count': 129, 'year': 1995, 'title': 'Bad Boys'},
#  {'count': 129, 'year': 2009, 'title': 'Avatar'},
#  {'count': 129, 'year': 2012, 'title': 'The Dark Knight Rises'},
#  {'count': 128, 'year': 2004, 'title': 'Troy'},
#  {'count': 128, 'year': 2002, 'title': 'Mr. Deeds'},
#  {'count': 128, 'year': 2006, 'title': 'Night at the Museum'},
#  {'count': 128, 'year': 1989, 'title': 'The Little Mermaid'},
#  {'count': 128, 'year': 2000, 'title': 'X-Men'},
#  {'count': 128, 'year': 1992, 'title': 'Sister Act'},
#  {'count': 128, 'year': 1997, 'title': 'Liar Liar'},
#  {'count': 128, 'year': 2008, 'title': 'The Curious Case of Benjamin Button'},
#  {'count': 128, 'year': 2002, 'title': 'A Walk to Remember'},
#  {'count': 128,
#   'year': 1997,
#   'title': 'Austin Powers: International Man of Mystery'},
#  {'count': 128, 'year': 1964, 'title': 'Mary Poppins'},
#  {'count': 128, 'year': 1997, 'title': 'Titanic'},
#  {'count': 128, 'year': 2004, 'title': 'A Cinderella Story'},
#  {'count': 128, 'year': 2008, 'title': 'Stop-Loss'},
#  {'count': 127, 'year': 1998, 'title': 'The Wedding Singer'},
#  {'count': 127, 'year': 2009, 'title': 'Funny People'},
#  {'count': 127, 'year': 2008, 'title': 'Taken'},
#  {'count': 127,
#   'year': 2002,
#   'title': 'The Lord of the Rings: The Two Towers'},
#  {'count': 127, 'year': 2008, 'title': 'Slumdog Millionaire'},
#  {'count': 127, 'year': 2009, 'title': 'Inglourious Basterds'},
#  {'count': 127,
#   'year': 2003,
#   'title': 'Pirates of the Caribbean: The Curse of the Black Pearl'},
#  {'count': 127, 'year': 2008, 'title': 'The Incredible Hulk'},
#  {'count': 126, 'year': 2002, 'title': 'Austin Powers in Goldmember'},
#  {'count': 126, 'year': 2003, 'title': 'Anger Management'},
#  {'count': 126, 'year': 1993, 'title': 'Mrs. Doubtfire'},
#  {'count': 126, 'year': 1955, 'title': 'Lady and the Tramp'},
#  {'count': 126, 'year': 1981, 'title': 'Raiders of the Lost Ark'},
#  {'count': 125, 'year': 1989, 'title': 'Batman'},
#  {'count': 125, 'year': 2001, 'title': 'Pearl Harbor'},
#  {'count': 125, 'year': 1991, 'title': 'Terminator 2: Judgment Day'},
#  {'count': 124,
#   'year': 1999,
#   'title': 'Austin Powers: The Spy Who Shagged Me'},
#  {'count': 124, 'year': 1998, 'title': 'Armageddon'},
#  {'count': 123, 'year': 2006, 'title': 'Cars'},
#  {'count': 123, 'year': 2007, 'title': 'National Treasure: Book of Secrets'},
#  {'count': 123, 'year': 2000, 'title': 'Scary Movie'},
#  {'count': 123,
#   'year': 2009,
#   'title': 'Harry Potter and the Half-Blood Prince'},
#  {'count': 122, 'year': 2009, 'title': 'Fighting'},
#  {'count': 122, 'year': 2007, 'title': "Ocean's Thirteen"},
#  {'count': 122, 'year': 2009, 'title': 'The Stepfather'},
#  {'count': 122, 'year': 1994, 'title': 'The Shawshank Redemption'},
#  {'count': 122, 'year': 2009, 'title': 'The Proposal'},
#  {'count': 122, 'year': 2003, 'title': 'The End of a Mystery'},
#  {'count': 121, 'year': 1998, 'title': "A Bug's Life"},
#  {'count': 121, 'year': 2009, 'title': 'The Invention of Lying'},
#  {'count': 121, 'year': 1991, 'title': 'The Silence of the Lambs'},
#  {'count': 121, 'year': 2005, 'title': 'Madagascar'},
#  {'count': 121, 'year': 2008, 'title': 'Quarantine'},
#  {'count': 121, 'year': 2009, 'title': 'G-Force'},
#  {'count': 121, 'year': 1994, 'title': 'Pulp Fiction'},
#  {'count': 120, 'year': 1971, 'title': 'Willy Wonka & the Chocolate Factory'},
#  {'count': 120, 'year': 2003, 'title': 'Finding Nemo'},
#  {'count': 119, 'year': 2009, 'title': 'Watchmen'},
#  {'count': 119, 'year': 2005, 'title': 'Harry Potter and the Goblet of Fire'},
#  {'count': 119, 'year': 1978, 'title': 'Grease'},
#  {'count': 119, 'year': 2012, 'title': 'The Hunger Games'},
#  {'count': 119, 'year': 1995, 'title': 'Jumanji'},
#  {'count': 119, 'year': 1999, 'title': '10 Things I Hate About You'},
#  {'count': 118, 'year': 1961, 'title': '101 Dalmatians'},
#  {'count': 117, 'year': 2012, 'title': 'The Avengers'},
#  {'count': 117, 'year': 2009, 'title': 'Orphan'},
#  {'count': 117, 'year': 2005, 'title': 'Saw II'},
#  {'count': 117,
#   'year': 2002,
#   'title': 'Star Wars: Episode II - Attack of the Clones'},
#  {'count': 116, 'year': 2003, 'title': 'Love Actually'},
#  {'count': 116, 'year': 2003, 'title': 'Scary Movie 3'},
#  {'count': 115, 'year': 2006, 'title': 'The Departed'},
#  {'count': 115, 'year': 1987, 'title': 'Dirty Dancing'},
#  {'count': 115, 'year': 2002, 'title': 'Sweet Home Alabama'},
#  {'count': 115,
#   'year': 1980,
#   'title': 'Star Wars: Episode V - The Empire Strikes Back'},
#  {'count': 115, 'year': 2003, 'title': 'How to Lose a Guy in 10 Days'},
#  {'count': 115, 'year': 1990, 'title': 'Edward Scissorhands'},
#  {'count': 115, 'year': 2001, 'title': 'Scary Movie 2'},
#  {'count': 115,
#   'year': 2006,
#   'title': 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan'},
#  {'count': 114, 'year': 2007, 'title': 'Hairspray'},
#  {'count': 114,
#   'year': 2001,
#   'title': 'The Lord of the Rings: The Fellowship of the Ring'},
#  {'count': 113, 'year': 2007, 'title': 'Disturbia'},
#  {'count': 111, 'year': 2000, 'title': 'Coyote Ugly'},
#  {'count': 111, 'year': 2007, 'title': 'American Gangster'},
#  {'count': 111, 'year': 2009, 'title': 'District 9'},
#  {'count': 111, 'year': 2000, 'title': "Charlie's Angels"},
#  {'count': 109, 'year': 2012, 'title': 'The Amazing Spider-Man'},
#  {'count': 108, 'year': 1992, 'title': 'Home Alone 2: Lost in New York'},
#  {'count': 107, 'year': 2007, 'title': 'Norbit'},
#  {'count': 5, 'year': 1995, 'title': 'The Cure'},
#  {'count': 4, 'year': 2010, 'title': 'Night Catches Us'},
#  {'count': 4,
#   'year': 2003,
#   'title': 'Cowards Bend the Knee or The Blue Hands'},
#  {'count': 4, 'year': 2008, 'title': 'The Women'},
#  {'count': 4, 'year': 2012, 'title': 'Compliance'},
#  {'count': 4, 'year': 1972, 'title': 'Play It Again, Sam'},
#  {'count': 4, 'year': 2009, 'title': 'Splice'},
#  {'count': 3, 'year': 2003, 'title': 'Proteus'},
#  {'count': 3, 'year': 2009, 'title': 'Bride Wars'},
#  {'count': 3, 'year': 1949, 'title': "Occupe-toi d'Amèlie..!"},
#  {'count': 3, 'year': 1996, 'title': "Dead Man's Walk"},
#  {'count': 3, 'year': 1972, 'title': 'Silent Running'},
#  {'count': 3, 'year': 1998, 'title': 'Return to Paradise'},
#  {'count': 3, 'year': 2014, 'title': 'Cesar Chavez'},
#  {'count': 3, 'year': 2013, 'title': 'Jibeuro ganeun gil'},
#  {'count': 3, 'year': 2004, 'title': 'The Terminal'},
#  {'count': 3, 'year': 2000, 'title': 'Bonhoeffer: Agent of Grace'},
#  {'count': 3, 'year': 1996, 'title': "Lilian's Story"},
#  {'count': 3, 'year': 1996, 'title': "Jackie Chan's First Strike"},
#  {'count': 3, 'year': 1983, 'title': 'Max Dugan Returns'},
#  {'count': 3, 'year': 1963, 'title': 'Yesterday, Today and Tomorrow'},
#  {'count': 3, 'year': 2014, 'title': 'Misconception'},
#  {'count': 3, 'year': 2007, 'title': 'City of Men'},
#  {'count': 3, 'year': 1992, 'title': 'The Boys of St. Vincent'},
#  {'count': 3, 'year': 2009, 'title': 'Someone Like You'},
#  {'count': 3, 'year': 1994, 'title': 'Pom Poko'},
#  {'count': 3, 'year': 2009, 'title': 'Rabbit è la Berlin'},
#  {'count': 3, 'year': 2013, 'title': 'Stand Clear of the Closing Doors'},
#  {'count': 3, 'year': 2011, 'title': 'The Unknown Woman'},
#  {'count': 3, 'year': 2013, 'title': 'American Courtesans'},
#  {'count': 3, 'year': 2007, 'title': 'Exte: Hair Extensions'},
#  {'count': 3, 'year': 2015, 'title': 'Tired Moonlight'},
#  {'count': 3, 'year': 2011, 'title': 'Overheard 2'},
#  {'count': 3, 'year': 2009, 'title': 'Cairo Time'},
#  {'count': 3, 'year': 2010, 'title': 'Pink Saris'},
#  {'count': 3, 'year': 1978, 'title': 'La Cage aux Folles'},
#  {'count': 3, 'year': 2004, 'title': 'Cube Zero'},
#  {'count': 3, 'year': 1972, 'title': 'Horror Express'},
#  {'count': 3, 'year': 1981, 'title': 'Duelul'},
#  {'count': 3, 'year': 1965, 'title': 'The Cincinnati Kid'},
#  {'count': 3, 'year': 2001, 'title': 'The Rising Place'},
#  {'count': 3, 'year': 1997, 'title': 'The House'},
#  {'count': 3, 'year': 1985, 'title': 'Twice in a Lifetime'},
#  {'count': 3, 'year': 2008, 'title': 'I Am So Proud of You'},
#  {'count': 3, 'year': 1988, 'title': 'High Spirits'},
#  {'count': 3, 'year': 1964, 'title': 'King & Country'},
#  {'count': 3, 'year': 1997, 'title': 'The Boxer'},
#  {'count': 3, 'year': 2015, 'title': '45 Years'},
#  {'count': 3, 'year': 1955, 'title': 'Footsteps in the Fog'},
#  {'count': 3, 'year': 2005, 'title': 'Wah-Wah'},
#  {'count': 3, 'year': 1999, 'title': 'Bartok the Magnificent'},
#  {'count': 3, 'year': 2008, 'title': 'La buena nueva'},
#  {'count': 3, 'year': 2006, 'title': 'Nacho Libre'},
#  {'count': 3, 'year': 2012, 'title': 'Lord of Darkness'},
#  {'count': 3,
#   'year': 2014,
#   'title': 'Never Tear Us Apart: The Untold Story of INXS'},
#  {'count': 3, 'year': 2011, 'title': 'Bringing Ashley Home'},
#  {'count': 3, 'year': 1995, 'title': 'Forgotten Silver'},
#  {'count': 3, 'year': 2014, 'title': 'Nas: Time Is Illmatic'},
#  {'count': 3, 'year': 2006, 'title': 'Palimpsest'},
#  {'count': 3, 'year': 2001, 'title': 'Jurassic Park III'},
#  {'count': 3, 'year': 2015, 'title': 'The Saboteurs'},
#  {'count': 3, 'year': 2013, 'title': 'Metalhead'},
#  {'count': 3, 'year': 2001, 'title': 'When Good Ghouls Go Bad'},
#  {'count': 3, 'year': 1960, 'title': 'The Apartment'},
#  {'count': 3, 'year': 2000, 'title': 'Happenstance'},
#  {'count': 3, 'year': 1990, 'title': "Betsy's Wedding"},
#  {'count': 3, 'year': 1997, 'title': 'Chile, the Obstinate Memory'},
#  {'count': 3, 'year': 2001, 'title': '61*'},
#  {'count': 3, 'year': 1999, 'title': 'Mystery Men'},
#  {'count': 3, 'year': 1968, 'title': "Je t'aime je t'aime"},
#  {'count': 3, 'year': 2010, 'title': 'Good Neighbors'},
#  {'count': 3, 'year': 2011, 'title': 'The Moth Diaries'},
#  {'count': 3, 'year': 2006, 'title': 'Comeback Season'},
#  {'count': 3, 'year': 1989, 'title': 'The Cow'},
#  {'count': 3, 'year': 1975, 'title': 'The Promised Land'},
#  {'count': 3, 'year': 2004, 'title': 'Black Cloud'},
#  {'count': 3, 'year': 2001, 'title': 'Green Dragon'},
#  {'count': 3, 'year': 1994, 'title': 'Federal Hill'},
#  {'count': 3, 'year': 2014, 'title': 'Plastic'},
#  {'count': 3, 'year': 1991, 'title': 'Black Robe'},
#  {'count': 3, 'year': 1999, 'title': 'Deterrence'},
#  {'count': 3, 'year': 2014, 'title': 'Exists'},
#  {'count': 3, 'year': 1996, 'title': 'Drifting Clouds'},
#  {'count': 3, 'year': 1976, 'title': 'The House by the Lake'},
#  {'count': 3, 'year': 1992, 'title': 'The Mighty Ducks'},
#  {'count': 3, 'year': 2008, 'title': 'Batman: Gotham Knight'},
#  {'count': 3, 'year': 1971, 'title': 'Duck, You Sucker'},
#  {'count': 3, 'year': 2010, 'title': 'Midnight FM'},
#  {'count': 3, 'year': 2009, 'title': 'Slice'},
#  {'count': 3, 'year': 2014, 'title': 'They Are All Dead'},
#  {'count': 3, 'year': 1955, 'title': 'Taira Clan Saga'},
#  {'count': 3, 'year': 2009, 'title': 'The Dark House'},
#  {'count': 3, 'year': 2000, 'title': '3rd World Hero'},
#  {'count': 3, 'year': 2012, 'title': 'Jesse Stone: Benefit of the Doubt'},
#  {'count': 3, 'year': 2006, 'title': 'Robin-B-Hood'},
#  {'count': 3, 'year': 1927, 'title': 'Upstream'},
#  {'count': 3, 'year': 2004, 'title': 'Ten Skies'},
#  {'count': 3, 'year': 2010, 'title': "The King's Speech"},
#  {'count': 3, 'year': 2006, 'title': 'The Valet'},
#  {'count': 3, 'year': 2005, 'title': 'Syriana'},
#  {'count': 3, 'year': 1961, 'title': 'A Wife Confesses'},
#  {'count': 3, 'year': 1989, 'title': 'Cold Feet'},
#  {'count': 3, 'year': 1977, 'title': 'Scott Joplin'},
#  {'count': 3, 'year': 1960, 'title': 'Macario'},
#  {'count': 3, 'year': 2013, 'title': 'SAGA: Curse of the Shadow'},
#  {'count': 3, 'year': 2015, 'title': '3 1/2 Minutes, Ten Bullets'},
#  {'count': 3, 'year': 2010, 'title': 'Great Migrations'},
#  {'count': 3, 'year': 2000, 'title': "Everybody's Famous!"},
#  {'count': 3, 'year': 2010, 'title': 'Bleak Night'},
#  {'count': 3, 'year': 1976, 'title': "That's Entertainment, Part II"},
#  {'count': 3, 'year': 1997, 'title': 'Amistad'},
#  {'count': 3, 'year': 2014, 'title': 'Inherent Vice'},
#  {'count': 3, 'year': 2003, 'title': 'Hitler: The Rise of Evil'},
#  {'count': 3, 'year': 2011, 'title': 'Without Men'},
#  {'count': 3, 'year': 1992, 'title': 'Christmas in Connecticut'},
#  {'count': 3, 'year': 1992, 'title': 'Honey I Blew Up the Kid'},
#  {'count': 3, 'year': 2005, 'title': 'Bionicle 3: Web of Shadows'},
#  {'count': 3, 'year': 1993, 'title': 'Return of the Living Dead III'},
#  {'count': 3, 'year': 1975, 'title': 'Euridice BA 2O37'},
#  {'count': 3, 'year': 2015, 'title': 'The Shaman'},
#  {'count': 3, 'year': 2009, 'title': 'Obitaemyy ostrov. Skhvatka'},
#  {'count': 3, 'year': 1954, 'title': 'Chronicle of Poor Lovers'},
#  {'count': 3, 'year': 2004, 'title': 'The Motorcycle Diaries'},
#  {'count': 3, 'year': 2004, 'title': 'Dig!'},
#  {'count': 3, 'year': 1990, 'title': 'Werner - Beinhart!'},
#  {'count': 3, 'year': 1986, 'title': 'From Beyond'},
#  {'count': 3, 'year': 2006, 'title': 'Naming Number Two'},
#  {'count': 3, 'year': 2011, 'title': 'Beauty Day'},
#  {'count': 3, 'year': 2007, 'title': 'Epic Movie'},
#  {'count': 3, 'year': 2005, 'title': 'Kiss Kiss Bang Bang'},
#  {'count': 3, 'year': 1998, 'title': 'A True Mob Story'},
#  {'count': 3, 'year': 2013, 'title': 'Olympus Has Fallen'},
#  {'count': 3, 'year': 2013, 'title': 'Monster High: Friday Night Frights'},
#  {'count': 3, 'year': 1961, 'title': 'The Roman Spring of Mrs. Stone'},
#  {'count': 3, 'year': 2006, 'title': 'Mr. Average'},
#  {'count': 3, 'year': 2009, 'title': 'Peter and Vandy'},
#  {'count': 3, 'year': 2010, 'title': 'The Dark Side of Chocolate'},
#  {'count': 3, 'year': 2010, 'title': 'Date Night'},
#  {'count': 3, 'year': 2010, 'title': 'Metrobranding'},
#  {'count': 3, 'year': 1996, 'title': 'Moebius'},
#  {'count': 3, 'year': 2013, 'title': 'Gangster Squad'},
#  {'count': 3, 'year': 1960, 'title': 'Midnight Lace'},
#  {'count': 3, 'year': 1977, 'title': 'Roots'},
#  {'count': 2, 'year': 1965, 'title': 'Triumph Over Violence'},
#  {'count': 2, 'year': 1996, 'title': 'Up Close & Personal'},
#  {'count': 2, 'year': 2013, 'title': 'The Noble Family'},
#  {'count': 2, 'year': 1999, 'title': 'Luna Papa'},
#  {'count': 2, 'year': 2002, 'title': 'Fixing Frank'},
#  {'count': 2, 'year': 1983, 'title': 'The Black Stallion Returns'},
#  {'count': 2, 'year': 2012, 'title': 'Helter Skelter'},
#  {'count': 2, 'year': 1987, 'title': 'Wings of Desire'},
#  {'count': 2, 'year': 1989, 'title': 'Homer and Eddie'},
#  {'count': 2, 'year': 1938, 'title': "You Can't Take It With You"},
#  {'count': 2, 'year': 2010, 'title': 'White Lion'},
#  {'count': 2, 'year': 2009, 'title': 'An Englishman in New York'},
#  {'count': 2, 'year': 1981, 'title': 'Lola'},
#  {'count': 2, 'year': 2014, 'title': 'The Greggs'},
#  {'count': 2, 'year': 2006, 'title': 'Choking Man'},
#  {'count': 2, 'year': 1999, 'title': 'My Little Business'},
#  {'count': 2, 'year': 2006, 'title': "Pao's Story"},
#  {'count': 2, 'year': 2006, 'title': 'Out of the Blue'},
#  {'count': 2, 'year': 1992, 'title': 'A League of Their Own'},
#  {'count': 2, 'year': 2012, 'title': 'Mann tut was Mann kann'},
#  {'count': 2, 'year': 2013, 'title': 'The Blue Umbrella'},
#  {'count': 2, 'year': 2011, 'title': 'Thor'},
#  {'count': 2, 'year': 2000, 'title': 'What Lies Beneath'},
#  {'count': 2, 'year': 2011, 'title': 'Tom and Jerry & The Wizard of Oz'},
#  {'count': 2, 'year': 1969, 'title': 'The Assassination Bureau'},
#  {'count': 2, 'year': 2007, 'title': 'Crows Zero'},
#  {'count': 2, 'year': 2010, 'title': 'Yogi Bear'},
#  {'count': 2, 'year': 1957, 'title': "A Tailor's Maid"},
#  {'count': 2, 'year': 2014, 'title': 'The Boxcar Children'},
#  {'count': 2, 'year': 1984, 'title': 'C.H.U.D.'},
#  {'count': 2, 'year': 2013, 'title': 'Joanna'},
#  {'count': 2, 'year': 2006, 'title': "Charlotte's Web"},
#  {'count': 2, 'year': 2009, 'title': 'Looking for Eric'},
#  {'count': 2, 'year': 1968, 'title': 'Asfalttilampaat'},
#  {'count': 2, 'year': 1986, 'title': 'El amor brujo'},
#  {'count': 2, 'year': 2014, 'title': 'The Longest Week'},
#  {'count': 2, 'year': 2009, 'title': 'Big River Man'},
#  {'count': 2, 'year': 2001, 'title': 'Super 8 Stories'},
#  {'count': 2, 'year': 1954, 'title': 'Brigadoon'},
#  {'count': 2, 'year': 1955, 'title': 'Trial'},
#  {'count': 2, 'year': 2007, 'title': 'Boy A'},
#  {'count': 2, 'year': 1954, 'title': 'The Vanishing Prairie'},
#  {'count': 2, 'year': 1989, 'title': 'Always'},
#  {'count': 2, 'year': 1999, 'title': 'Grizzly Falls'},
#  {'count': 2, 'year': 2007, 'title': 'Pop Skull'},
#  {'count': 2, 'year': 1993, 'title': 'Wandering Sagittarius'},
#  {'count': 2, 'year': 2004, 'title': "Love's Enduring Promise"},
#  {'count': 2, 'year': 2005, 'title': 'Secret Smile'},
#  {'count': 2, 'year': 2015, 'title': 'In the Grayscale'},
#  {'count': 2, 'year': 1971, 'title': 'THX 1138'},
#  {'count': 2, 'year': 2009, 'title': 'Sex, Party and Lies'},
#  {'count': 2, 'year': 2007, 'title': 'Pathfinder'},
#  {'count': 2, 'year': 2013, 'title': 'The Numbers Station'},
#  {'count': 2, 'year': 2011, 'title': 'Shock Head Soul'},
#  {'count': 2, 'year': 2003, 'title': 'Thirteen'},
#  {'count': 2, 'year': 1955, 'title': 'The Bachelor'},
#  {'count': 2, 'year': 2012, 'title': 'Wreck-It Ralph'},
#  {'count': 2, 'year': 2014, 'title': 'One-Minute Time Machine'},
#  {'count': 2, 'year': 1981, 'title': "Cutter's Way"},
#  {'count': 2, 'year': 2013, 'title': 'Leave to Remain'},
#  {'count': 2, 'year': 2013, 'title': 'The Terror Live'},
#  {'count': 2, 'year': 2006, 'title': 'The Education of Fairies'},
#  {'count': 2, 'year': 2008, 'title': 'Disaster Movie'},
#  {'count': 2, 'year': 1958, 'title': 'Ride a Crooked Trail'},
#  {'count': 2, 'year': 2014, 'title': 'The Book of Life'},
#  {'count': 2, 'year': 2012, 'title': 'Zarafa'},
#  {'count': 2, 'year': 1990, 'title': 'On Tour'},
#  {'count': 2, 'year': 2011, 'title': 'Delicacy'},
#  {'count': 2, 'year': 1968, 'title': 'Charly'},
#  {'count': 2, 'year': 1998, 'title': 'Ronin'},
#  {'count': 2, 'year': 1998, 'title': 'Hitman Hart: Wrestling with Shadows'},
#  {'count': 2, 'year': 2013, 'title': 'The Returned'},
#  {'count': 2, 'year': 2004, 'title': 'Miracle'},
#  {'count': 2, 'year': 2001, 'title': 'Soft Shell Man'},
#  {'count': 2, 'year': 2009, 'title': 'Tetro'},
#  {'count': 2, 'year': 1978, 'title': 'Don'},
#  {'count': 2, 'year': 2002, 'title': 'R.S.V.P.'},
#  {'count': 2, 'year': 1998, 'title': 'The Siege'},
#  {'count': 2, 'year': 1987, 'title': 'Blind Date'},
#  {'count': 2, 'year': 2012, 'title': 'Small Apartments'},
#  {'count': 2, 'year': 2008, 'title': 'The Children'},
#  {'count': 2, 'year': 2012, 'title': '009 Re: Cyborg'},
#  {'count': 2, 'year': 1978, 'title': 'Interiors'},
#  {'count': 2, 'year': 2007, 'title': 'Red Ants'},
#  {'count': 2, 'year': 1990, 'title': 'Eating'},
#  {'count': 2, 'year': 1976, 'title': 'Bugsy Malone'},
#  {'count': 2, 'year': 1998, 'title': 'Pocahontas II: Journey to a New World'},
#  {'count': 2, 'year': 2000, 'title': 'Come Undone'},
#  {'count': 2, 'year': 2011, 'title': 'Century of Birthing'},
#  {'count': 2, 'year': 2004, 'title': 'Addictions and Subtractions'},
#  {'count': 2,
#   'year': 1999,
#   'title': 'Joseph and the Amazing Technicolor Dreamcoat'},
#  {'count': 2, 'year': 1980, 'title': 'The Age of the Earth'},
#  {'count': 2, 'year': 2005, 'title': 'Hiroshima'},
#  {'count': 2, 'year': 2007, 'title': 'Anna M.'},
#  {'count': 2, 'year': 1991, 'title': 'Hors la vie'},
#  {'count': 2, 'year': 1999, 'title': 'Notting Hill'},
#  {'count': 2, 'year': 2002, 'title': 'Spun'},
#  {'count': 2, 'year': 2013, 'title': 'The Wizards Return: Alex vs. Alex'},
#  {'count': 2, 'year': 2015, 'title': 'Equals'},
#  {'count': 2, 'year': 2013, 'title': 'Ambassada'},
#  {'count': 2, 'year': 2005, 'title': 'Verlengd weekend'},
#  {'count': 2, 'year': 2005, 'title': 'Cinderella Man'},
#  {'count': 2, 'year': 2001, 'title': 'Tremors 3: Back to Perfection'},
#  {'count': 2, 'year': 2009, 'title': 'Beetle Queen Conquers Tokyo'},
#  {'count': 2, 'year': 1981, 'title': 'The War of the Worlds: Next Century'},
#  {'count': 2, 'year': 1998, 'title': 'Glasblèsarns barn'},
#  {'count': 2, 'year': 2007, 'title': 'The Signal'},
#  {'count': 2, 'year': 1996, 'title': 'The Dentist'},
#  {'count': 2, 'year': 1984, 'title': 'Godzilla 1985'},
#  {'count': 2, 'year': 2008, 'title': 'The Love Guru'},
#  {'count': 2, 'year': 1995, 'title': 'Mosquito'},
#  {'count': 2, 'year': 2012, 'title': 'Dead Man Talking'},
#  {'count': 2, 'year': 2008, 'title': 'Painted Skin'},
#  {'count': 2, 'year': 1990, 'title': 'Mister Johnson'},
#  {'count': 2, 'year': 1984, 'title': 'Against All Odds'},
#  {'count': 2, 'year': 1999, 'title': 'The Corruptor'},
#  {'count': 2, 'year': 1991, 'title': 'Lucky Luke'},
#  {'count': 2, 'year': 1994, 'title': 'Lakota Woman: Siege at Wounded Knee'},
#  {'count': 2, 'year': 2015, 'title': 'The Adderall Diaries'},
#  {'count': 2, 'year': 1998, 'title': 'Beefcake'},
#  {'count': 2, 'year': 2012, 'title': 'The Last Sentence'},
#  {'count': 2, 'year': 1989, 'title': 'Robot Jox'},
#  {'count': 2, 'year': 1926, 'title': 'The Strong Man'},
#  {'count': 2, 'year': 2010, 'title': 'Tooth Fairy'},
#  {'count': 2, 'year': 1956, 'title': 'The Catered Affair'},
#  {'count': 2, 'year': 2009, 'title': 'Year One'},
#  {'count': 2, 'year': 2010, 'title': 'Morgen'},
#  {'count': 2, 'year': 2013, 'title': 'Teenage'},
#  {'count': 2, 'year': 1989, 'title': 'Johnny Handsome'},
#  {'count': 2, 'year': 2010, 'title': 'The Names of Love'},
#  {'count': 2, 'year': 1977, 'title': 'Between the Lines'},
#  {'count': 2, 'year': 1998, 'title': 'The Big Lebowski'},
#  {'count': 2, 'year': 2003, 'title': 'So Normal'},
#  {'count': 2, 'year': 1984, 'title': '28 Up'},
#  {'count': 2, 'year': 1987, 'title': 'Someone to Watch Over Me'},
#  {'count': 2, 'year': 2009, 'title': 'Mother and Child'},
#  {'count': 2, 'year': 1977, 'title': 'In the Name of the Pope King'},
#  {'count': 2, 'year': 1970, 'title': 'The Breach'},
#  {'count': 2, 'year': 2006, 'title': 'Lady in the Water'},
#  {'count': 2, 'year': 2013, 'title': 'Blue Caprice'},
#  {'count': 2, 'year': 2012, 'title': 'Motorway'},
#  {'count': 2, 'year': 1999, 'title': 'Annaluise & Anton'},
#  {'count': 2, 'year': 1972, 'title': 'The Carey Treatment'},
#  {'count': 2, 'year': 2007, 'title': 'Shotgun Stories'},
#  {'count': 2, 'year': 2015, 'title': 'Call Me Lucky'},
#  {'count': 2, 'year': 2005, 'title': 'China Blue'},
#  {'count': 2, 'year': 2014, 'title': 'Cruel & Unusual'},
#  {'count': 2, 'year': 2012, 'title': 'Not Suitable for Children'},
#  {'count': 2, 'year': 2013, 'title': 'Mèbius'},
#  {'count': 2, 'year': 2007, 'title': "The Band's Visit"},
#  {'count': 2, 'year': 1986, 'title': 'The Adventure of Faustus Bidgood'},
#  {'count': 2, 'year': 2006, 'title': 'Khottabych'},
#  {'count': 2, 'year': 2004, 'title': "We Don't Live Here Anymore"},
#  {'count': 2, 'year': 2013, 'title': 'Decency'},
#  {'count': 2, 'year': 1972, 'title': 'Schoolgirls Growing Up'},
#  {'count': 2, 'year': 1955, 'title': 'The End of the Affair'},
#  {'count': 2, 'year': 2006, 'title': 'First Flight'},
#  {'count': 2, 'year': 2006, 'title': '4 Minutes'},
#  {'count': 2, 'year': 2012, 'title': 'The Delay'},
#  {'count': 2, 'year': 2001, 'title': 'Me and Morrison'},
#  {'count': 2, 'year': 2004, 'title': 'Hardcore'},
#  {'count': 2, 'year': 2008, 'title': 'Sarkar Raj'},
#  {'count': 2, 'year': 1956, 'title': 'Crashing Las Vegas'},
#  {'count': 2, 'year': 1979, 'title': 'Rich Kids'},
#  {'count': 2, 'year': 2011, 'title': 'Saheb Biwi Aur Gangster'},
#  {'count': 2, 'year': 2013, 'title': 'Made in America'},
#  {'count': 2, 'year': 2001, 'title': 'Large'},
#  {'count': 2, 'year': 2008, 'title': 'Oye Lucky! Lucky Oye!'},
#  {'count': 2, 'year': 1999, 'title': 'Life, Autumn'},
#  {'count': 2, 'year': 2011, 'title': 'Summer Games'},
#  {'count': 2, 'year': 1999, 'title': 'Miss Julie'},
#  {'count': 2, 'year': 1989, 'title': 'Ghostbusters II'},
#  {'count': 2, 'year': 1995, 'title': 'Mother Dao, the Turtlelike'},
#  {'count': 2, 'year': 2004, 'title': 'Mickybo and Me'},
#  {'count': 2, 'year': 2011, 'title': 'Familiar Grounds'},
#  {'count': 2, 'year': 2014, 'title': 'White Bird in a Blizzard'},
#  {'count': 2, 'year': 2002, 'title': 'OT: Our Town'},
#  {'count': 2, 'year': 2015, 'title': 'Youth'},
#  {'count': 2, 'year': 2011, 'title': 'The Painting'},
#  {'count': 2, 'year': 2007, 'title': 'Son of Rambow'},
#  {'count': 2, 'year': 2013, 'title': "A Birder's Guide to Everything"},
#  {'count': 2, 'year': 2014, 'title': 'Yves Saint Laurent'},
#  {'count': 2, 'year': 1959, 'title': 'Gidget'},
#  {'count': 2, 'year': 1955, 'title': 'The Kentuckian'},
#  {'count': 2, 'year': 1981, 'title': 'Cattle Annie and Little Britches'},
#  {'count': 2, 'year': 1999, 'title': 'Butterfly'},
#  {'count': 2, 'year': 1984, 'title': 'City Heat'},
#  {'count': 2, 'year': 2010, 'title': 'Men Vs Women'},
#  {'count': 2, 'year': 2008, 'title': 'Yesterday Was a Lie'},
#  {'count': 2, 'year': 1952, 'title': 'Room for One More'},
#  {'count': 2, 'year': 1995, 'title': 'The Mangler'},
#  {'count': 2, 'year': 1988, 'title': 'Cocktail'},
#  {'count': 2, 'year': 2006, 'title': 'Corporate'},
#  {'count': 2, 'year': 2012, 'title': 'Elliot Loves'},
#  {'count': 2, 'year': 1993, 'title': 'Jack the Bear'},
#  {'count': 2, 'year': 2012, 'title': 'Storage 24'},
#  {'count': 2, 'year': 2000, 'title': 'The Endurance'},
#  {'count': 2,
#   'year': 2008,
#   'title': 'The Crimson Wing: Mystery of the Flamingos'},
#  {'count': 2, 'year': 1994, 'title': 'Lakota Woman: Siege at Wounded Knee'},
#  {'count': 2, 'year': 2008, 'title': 'Semi-Pro'},
#  {'count': 2, 'year': 1997, 'title': 'The Castle'},
#  {'count': 2, 'year': 2013, 'title': "Fanie Fourie's Lobola"},
#  {'count': 2, 'year': 2006, 'title': 'The Professor and His Beloved Equation'},
#  {'count': 2, 'year': 2001, 'title': 'Pulse'},
#  {'count': 2, 'year': 1965, 'title': 'Three'},
#  {'count': 2, 'year': 2014, 'title': 'The Imitation Game'},
#  {'count': 2, 'year': 1995, 'title': 'Black Day Blue Night'},
#  {'count': 2, 'year': 2010, 'title': 'Jack Goes Boating'},
#  {'count': 2, 'year': 1964, 'title': 'Marnie'},
#  {'count': 2, 'year': 1997, 'title': 'Sue'},
#  {'count': 2, 'year': 2013, 'title': 'Lad: A Yorkshire Story'},
#  {'count': 2, 'year': 2014, 'title': 'Messi'},
#  {'count': 2, 'year': 2013, 'title': 'Adult World'},
#  {'count': 2, 'year': 1969, 'title': 'Goyokin'},
#  {'count': 2, 'year': 1979, 'title': 'Galaxy Express 999'},
#  {'count': 2, 'year': 2000, 'title': 'Wild Flowers'},
#  {'count': 2,
#   'year': 2009,
#   'title': 'Genius Within: The Inner Life of Glenn Gould'},
#  {'count': 2, 'year': 1999, 'title': "Lord's Lantern in Budapest"},
#  {'count': 2, 'year': 2000, 'title': 'Rated X'},
#  {'count': 2, 'year': 2011, 'title': 'Hell and Back Again'},
#  {'count': 2, 'year': 2013, 'title': 'American Promise'},
#  {'count': 2, 'year': 1973, 'title': 'Oklahoma Crude'},
#  {'count': 2, 'year': 2015, 'title': 'The Lobster'},
#  {'count': 2, 'year': 1997, 'title': 'Addicted to Love'},
#  {'count': 2, 'year': 1994, 'title': 'Lèon: The Professional'},
#  {'count': 2, 'year': 2010, 'title': 'Barbie in a Mermaid Tale'},
#  {'count': 2, 'year': 1990, 'title': 'Die Hard 2'},
#  {'count': 2, 'year': 2013, 'title': 'Oktober November'},
#  {'count': 2, 'year': 1984, 'title': 'The River'},
#  {'count': 2, 'year': 2007, 'title': 'Ya ostayus'},
#  {'count': 2, 'year': 2000, 'title': 'Cheap Smokes'},
#  {'count': 2, 'year': 1954, 'title': 'Somewhere Under the Broad Sky'},
#  {'count': 2, 'year': 2006, 'title': 'Venus'},
#  {'count': 2, 'year': 2000, 'title': 'The 6th Day'},
#  {'count': 2, 'year': 2002, 'title': 'Cubeè: Hypercube'},
#  {'count': 2, 'year': 2004, 'title': "Avellaneda's Moon"},
#  {'count': 2, 'year': 1948, 'title': 'Road House'},
#  {'count': 2, 'year': 1978, 'title': 'La escopeta nacional'},
#  {'count': 2, 'year': 1985, 'title': 'Return to Oz'},
#  {'count': 2, 'year': 1992, 'title': "I Don't Buy Kisses Anymore"},
#  {'count': 2, 'year': 1990, 'title': "Jacob's Ladder"},
#  {'count': 2, 'year': 2012, 'title': 'Justice League: Doom'},
#  {'count': 2, 'year': 2006, 'title': 'The Fox and the Hound 2'},
#  {'count': 2, 'year': 1981, 'title': 'Il minestrone'},
#  {'count': 2, 'year': 2015, 'title': 'April and the Extraordinary World'},
#  {'count': 2, 'year': 2000, 'title': "Girls Can't Swim"},
#  {'count': 2, 'year': 2008, 'title': 'WarGames: The Dead Code'},
#  {'count': 2, 'year': 2000, 'title': 'Battlefield Earth'},
#  {'count': 2, 'year': 2004, 'title': 'Ryan'},
#  {'count': 2, 'year': 1948, 'title': 'Yoru no onnatachi'},
#  {'count': 2, 'year': 2004, 'title': 'EuroTrip'},
#  {'count': 2, 'year': 1967, 'title': 'Barefoot in the Park'},
#  {'count': 2, 'year': 2002, 'title': '24 Hour Party People'},
#  {'count': 2, 'year': 1980, 'title': 'Rude Boy'},
#  {'count': 2, 'year': 1963, 'title': 'Marine Battleground'},
#  {'count': 2, 'year': 2010, 'title': 'Der letzte schène Herbsttag'},
#  {'count': 2, 'year': 1989, 'title': 'Cheetah'},
#  {'count': 2, 'year': 1957, 'title': 'Tizoc'},
#  {'count': 2, 'year': 2011, 'title': 'Red Riding Hood'},
#  {'count': 2, 'year': 2014, 'title': 'Concerning Violence'},
#  {'count': 2, 'year': 2008, 'title': 'Flash of Genius'},
#  {'count': 2, 'year': 2005, 'title': 'Boy s tenyu'},
#  {'count': 2, 'year': 2013, 'title': "Jodorowsky's Dune"},
#  {'count': 2, 'year': 1975, 'title': 'Dog Day Afternoon'},
#  {'count': 2, 'year': 1999, 'title': 'Catfish in Black Bean Sauce'},
#  {'count': 2, 'year': 2002, 'title': '9/11'},
#  {'count': 2, 'year': 1990, 'title': 'Jekyll & Hyde'},
#  {'count': 2, 'year': 2014, 'title': 'Ride Along'},
#  {'count': 2, 'year': 2003, 'title': 'The Pentagon Papers'},
#  {'count': 2, 'year': 2001, 'title': 'Brigham City'},
#  {'count': 2, 'year': 2011, 'title': 'The Giants'},
#  {'count': 2, 'year': 2004, 'title': 'Downfall'},
#  {'count': 2, 'year': 2006, 'title': 'The Unknown Soldier'},
#  {'count': 2, 'year': 1981, 'title': 'Possession'},
#  {'count': 2, 'year': 2003, 'title': 'Eloise at the Plaza'},
#  {'count': 2, 'year': 2012, 'title': 'The Raven'},
#  {'count': 2, 'year': 2001, 'title': "The Devil's Backbone"},
#  {'count': 2, 'year': 1995, 'title': 'Two Deaths'},
#  {'count': 2, 'year': 2012, 'title': 'To Rome with Love'},
#  {'count': 2, 'year': 1958, 'title': 'The Left Handed Gun'},
#  {'count': 2,
#   'year': 2013,
#   'title': 'We Steal Secrets: The Story of WikiLeaks'},
#  {'count': 2, 'year': 2005, 'title': "Refugee All Stars, Sierra Leone's"},
#  {'count': 2, 'year': 1980, 'title': 'The Nude Bomb'},
#  {'count': 2, 'year': 1979, 'title': 'The Great Santini'},
#  {'count': 2, 'year': 2007, 'title': 'Eye in the Sky'},
#  {'count': 2, 'year': 2001, 'title': "Say It Isn't So"},
#  {'count': 2, 'year': 1983, 'title': 'The Story of Piera'},
#  {'count': 2, 'year': 1963, 'title': 'The Caretakers'},
#  {'count': 2, 'year': 2009, 'title': "We Don't Care About Music Anyway"},
#  {'count': 2, 'year': 2013, 'title': "Thou Gild'st the Even"},
#  {'count': 2, 'year': 2005, 'title': 'Last Days'},
#  {'count': 2, 'year': 2008, 'title': 'The Bank Job'},
#  {'count': 2, 'year': 2011, 'title': 'Melancholia'},
#  {'count': 2, 'year': 2010, 'title': 'How Do You Know'},
#  {'count': 2, 'year': 2014, 'title': 'Just Eat It: A Food Waste Story'},
#  {'count': 2, 'year': 2000, 'title': 'Hellraiser: Inferno'},
#  {'count': 2, 'year': 1991, 'title': "I Don't Kiss"},
#  {'count': 2, 'year': 1991, 'title': 'Mississippi Masala'},
#  {'count': 2, 'year': 1998, 'title': 'Jack Frost'},
#  {'count': 2, 'year': 2010, 'title': 'Somewhere'},
#  {'count': 2, 'year': 2010, 'title': 'Due Date'},
#  {'count': 2, 'year': 2007, 'title': 'Look'},
#  {'count': 2, 'year': 2003, 'title': 'Where the Red Fern Grows'},
#  {'count': 2, 'year': 2011, 'title': 'Volcano'},
#  {'count': 2, 'year': 2011, 'title': 'The Intouchables'},
#  {'count': 2, 'year': 2010, 'title': 'Auk Nr. 8'},
#  {'count': 2, 'year': 2013, 'title': 'Beautiful Creatures'},
#  {'count': 2, 'year': 2005, 'title': 'Corpse Bride'},
#  {'count': 2, 'year': 2011, 'title': 'My Tomorrow'},
#  {'count': 2, 'year': 2015, 'title': 'Bitva za Sevastopol'},
#  {'count': 2, 'year': 2004, 'title': 'The Bridge of San Luis Rey'},
#  {'count': 2, 'year': 2013, 'title': "Forever's End"},
#  {'count': 2, 'year': 1981, 'title': 'Passion of Love'},
#  {'count': 2, 'year': 2006, 'title': 'We Are Marshall'},
#  {'count': 2, 'year': 2010, 'title': 'Thorne: Sleepyhead'},
#  {'count': 2, 'year': 2015, 'title': 'Polycarp'},
#  {'count': 2, 'year': 1999, 'title': 'Les convoyeurs attendent'},
#  {'count': 2, 'year': 2003, 'title': 'The Medallion'},
#  {'count': 2, 'year': 1988, 'title': 'Action Jackson'},
#  {'count': 2, 'year': 2000, 'title': 'The Art of War'},
#  {'count': 2, 'year': 2009, 'title': 'The Velveteen Rabbit'},
#  {'count': 2, 'year': 1999, 'title': 'A Slipping-Down Life'},
#  {'count': 2, 'year': 2007, 'title': 'Autohystoria'},
#  {'count': 2, 'year': 2014, 'title': 'Big Game'},
#  {'count': 2, 'year': 2003, 'title': 'Bonjour Monsieur Shlomi'},
#  {'count': 2, 'year': 2009, 'title': 'Daybreakers'},
#  {'count': 2, 'year': 2014, 'title': "I'm the One You Want"},
#  {'count': 2, 'year': 2011, 'title': 'A Heartbeat Away'},
#  {'count': 2, 'year': 2014, 'title': 'Pride'},
#  {'count': 2, 'year': 1992, 'title': 'American Heart'},
#  {'count': 2, 'year': 2011, 'title': 'The Awakening'},
#  {'count': 2, 'year': 2013, 'title': 'Amiche da morire'},
#  {'count': 2, 'year': 2013, 'title': 'Sword Art Online Extra Edition'},
#  {'count': 2, 'year': 1995, 'title': 'Kristin Lavransdatter'},
#  {'count': 2, 'year': 1995, 'title': 'Mondo'},
#  {'count': 2, 'year': 2009, 'title': 'Little Girl'},
#  {'count': 2, 'year': 1983, 'title': 'Testament'},
#  {'count': 2, 'year': 2007, 'title': 'Nocturna'},
#  {'count': 2, 'year': 2015, 'title': 'Wolf Totem'},
#  {'count': 2, 'year': 2002, 'title': 'Sorority Boys'},
#  {'count': 2, 'year': 1977, 'title': 'Slap Shot'},
#  {'count': 2, 'year': 1991, 'title': 'Kafka'},
#  {'count': 2, 'year': 1994, 'title': 'Zamok'},
#  {'count': 2, 'year': 2002, 'title': 'Devdas'},
#  {'count': 2, 'year': 2014, 'title': 'We Are Young. We Are Strong.'},
#  {'count': 2, 'year': 1994, 'title': "Nobody's Fool"},
#  {'count': 2, 'year': 2013, 'title': 'Min sèsters bèrn i Afrika'},
#  {'count': 2, 'year': 1987, 'title': 'The Witches of Eastwick'},
#  {'count': 2, 'year': 2014, 'title': 'Nightcrawler'},
#  {'count': 2, 'year': 2008, 'title': 'Our Beloved Month of August'},
#  {'count': 2, 'year': 2009, 'title': 'Carriers'},
#  {'count': 2, 'year': 1988, 'title': 'The Kiss'},
#  {'count': 2, 'year': 2007, 'title': 'Juno'},
#  {'count': 2, 'year': 2004, 'title': 'Torque'},
#  {'count': 2,
#   'year': 2005,
#   'title': "Marilyn Hotchkiss' Ballroom Dancing & Charm School"},
#  {'count': 2, 'year': 1987, 'title': 'China Girl'},
#  {'count': 2, 'year': 1950, 'title': 'The Magnificent Yankee'},
#  {'count': 2, 'year': 2004, 'title': 'Primer'},
#  {'count': 2, 'year': 1989, 'title': 'Noce blanche'},
#  {'count': 2, 'year': 2004, 'title': 'The Forgotten'},
#  {'count': 2, 'year': 1968, 'title': 'Isadora'},
#  {'count': 2, 'year': 2006, 'title': 'Running Scared'},
#  {'count': 2, 'year': 2008, 'title': 'Suspect X'},
#  {'count': 2, 'year': 2005, 'title': 'Melissa P.'},
#  {'count': 2, 'year': 2010, 'title': 'My Good Enemy'},
#  {'count': 2, 'year': 2011, 'title': 'Savage'},
#  {'count': 2, 'year': 2013, 'title': "Devil's Pass"},
#  {'count': 2, 'year': 2002, 'title': 'The Settlement'},
#  {'count': 2, 'year': 1957, 'title': 'Sissi: The Fateful Years of an Empress'},
#  {'count': 2,
#   'year': 2013,
#   'title': 'Temptation: Confessions of a Marriage Counselor'},
#  {'count': 2, 'year': 1997, 'title': 'What the Deaf Man Heard'},
#  {'count': 2, 'year': 1989, 'title': 'Love Without Pity'},
#  {'count': 2, 'year': 2012, 'title': 'The Wooden Bridge'},
#  {'count': 2, 'year': 2002, 'title': 'Knallharte Jungs'},
#  {'count': 2, 'year': 1991, 'title': 'Den ofrivillige golfaren'},
#  {'count': 2, 'year': 1970, 'title': 'The Things of Life'},
#  {'count': 2, 'year': 1987, 'title': 'The Stepfather'},
#  {'count': 2, 'year': 1979, 'title': 'Saint Jack'},
#  {'count': 2, 'year': 1998, 'title': 'Hitman Hart: Wrestling with Shadows'},
#  {'count': 2, 'year': 2015, 'title': 'Above and Below'},
#  {'count': 2, 'year': 2013, 'title': '10 Minutes'},
#  {'count': 2, 'year': 1967, 'title': 'I Even Met Happy Gypsies'},
#  {'count': 2, 'year': 1995, 'title': 'Fresh Bait'},
#  {'count': 2, 'year': 2013, 'title': 'Unbeatable'},
#  {'count': 2, 'year': 1974, 'title': 'The Clockmaker of St. Paul'},
#  {'count': 2,
#   'year': 1997,
#   'title': 'Breaking the Surface: The Greg Louganis Story'},
#  {'count': 2, 'year': 1999, 'title': 'Kiss Me in the Rain'},
#  {'count': 2, 'year': 1988, 'title': 'Mississippi Burning'},
#  {'count': 2, 'year': 1998, 'title': 'The Cruise'},
#  {'count': 2, 'year': 2013, 'title': 'Baggage Claim'},
#  {'count': 2, 'year': 2012, 'title': 'Ted'},
#  {'count': 2, 'year': 1993, 'title': 'My Favorite Season'},
#  {'count': 2, 'year': 2011, 'title': 'How to Stop Being a Loser'},
#  {'count': 2, 'year': 2014, 'title': "Marie's Story"},
#  {'count': 2, 'year': 2010, 'title': 'Steam of Life'},
#  {'count': 2, 'year': 2012, 'title': "Everybody's Got Somebody... Not Me"},
#  {'count': 2, 'year': 2002, 'title': 'The Time Machine'},
#  {'count': 2, 'year': 2008, 'title': 'The House of Small Cubes'},
#  {'count': 2, 'year': 2014, 'title': 'Songs She Wrote About People She Knows'},
#  {'count': 2, 'year': 2012, 'title': 'No'},
#  {'count': 2, 'year': 1966, 'title': 'La strega in amore'},
#  {'count': 2, 'year': 1985, 'title': 'Police Story'},
#  {'count': 2, 'year': 2012, 'title': 'Mars et Avril'},
#  {'count': 2, 'year': 2004, 'title': 'Species III'},
#  {'count': 2, 'year': 1999, 'title': 'The Bridge'},
#  {'count': 2, 'year': 2004, 'title': 'Tony Takitani'},
#  {'count': 2, 'year': 2012, 'title': 'Downeast'},
#  {'count': 2, 'year': 1969, 'title': 'The Rain People'},
#  {'count': 2, 'year': 1996, 'title': 'Shiloh'},
#  {'count': 2, 'year': 2004, 'title': "Dave Chappelle: For What It's Worth"},
#  {'count': 2, 'year': 2008, 'title': "What Doesn't Kill You"},
#  {'count': 2, 'year': 2011, 'title': 'The Union'},
#  {'count': 2, 'year': 2008, 'title': '21'},
#  {'count': 2, 'year': 1997, 'title': 'Tomorrow Never Dies'},
#  {'count': 2, 'year': 2005, 'title': 'Munich'},
#  {'count': 2, 'year': 1970, 'title': 'Pieces of Dreams'},
#  {'count': 2, 'year': 1971, 'title': 'The French Connection'},
#  {'count': 2, 'year': 1999, 'title': 'Best Laid Plans'},
#  {'count': 2, 'year': 2014, 'title': 'Whisper If I Forget'},
#  {'count': 2, 'year': 2002, 'title': 'The Santa Clause 2'},
#  {'count': 2, 'year': 2003, 'title': 'Bodysong'},
#  {'count': 2, 'year': 1962, 'title': '40 Pounds of Trouble'},
#  {'count': 2, 'year': 2007, 'title': 'Chaotic Ana'},
#  {'count': 2, 'year': 1979, 'title': 'I Am Maria'},
#  {'count': 2, 'year': 2002, 'title': 'An Injury to One'},
#  {'count': 2, 'year': 2008, 'title': 'Rozygrysh'},
#  {'count': 2, 'year': 2015, 'title': 'The Pearl Button'},
#  {'count': 2, 'year': 2000, 'title': 'Tadpole'},
#  {'count': 2, 'year': 2001, 'title': 'Truly Human'},
#  {'count': 2, 'year': 1980, 'title': 'Fatso'},
#  {'count': 2, 'year': 1958, 'title': 'Love Is My Profession'},
#  {'count': 2, 'year': 1970, 'title': 'Run, Simon, Run'},
#  {'count': 2, 'year': 2004, 'title': 'Catch That Kid'},
#  {'count': 2, 'year': 1974, 'title': 'Martha'},
#  {'count': 2, 'year': 2014, 'title': 'The Homesman'},
#  {'count': 2, 'year': 2006, 'title': 'Asterix and the Vikings'},
#  {'count': 2, 'year': 2005, 'title': 'Christmas in Boston'},
#  {'count': 2, 'year': 2008, 'title': 'Poppy Shakespeare'},
#  {'count': 2, 'year': 1999, 'title': 'Kiss Me in the Rain'},
#  {'count': 2, 'year': 1955, 'title': 'The Grand Maneuver'},
#  {'count': 2, 'year': 2013, 'title': 'Monica Z'},
#  {'count': 2, 'year': 1956, 'title': 'The Ogre of Athens'},
#  {'count': 2, 'year': 2002, 'title': 'Ju-on: The Grudge'},
#  {'count': 2, 'year': 2015, 'title': 'Ex Machina'},
#  {'count': 2, 'year': 2002, 'title': 'No Good Deed'},
#  {'count': 2, 'year': 2014, 'title': '20,000 Days on Earth'},
#  {'count': 2, 'year': 1978, 'title': 'Midnight Express'},
#  {'count': 2, 'year': 2002, 'title': 'Enough'},
#  {'count': 2, 'year': 2002, 'title': 'Flower & Garnet'},
#  {'count': 2,
#   'year': 2004,
#   'title': 'The End of Suburbia: Oil Depletion and the Collapse of the American Dream'},
#  {'count': 2, 'year': 2007, 'title': 'Appleseed Saga: Ex Machina'},
#  {'count': 2, 'year': 2002, 'title': 'Two Weeks Notice'},
#  {'count': 2, 'year': 2013, 'title': 'Hansel & Gretel: Witch Hunters'},
#  {'count': 2, 'year': 2001, 'title': "Varian's War"},
#  {'count': 2, 'year': 2005, 'title': 'Quo Vadis, Baby?'},
#  {'count': 2, 'year': 2014, 'title': 'Suburban Gothic'},
#  {'count': 2, 'year': 2005, 'title': 'The Dark Hours'},
#  {'count': 2, 'year': 1981, 'title': "Porky's"},
#  {'count': 2,
#   'year': 2005,
#   'title': "I'm King Kong!: The Exploits of Merian C. Cooper"},
#  {'count': 2, 'year': 2010, 'title': "I'm Still Here"},
#  {'count': 2, 'year': 2012, 'title': 'The Floating Castle'},
#  {'count': 2, 'year': 1996, 'title': 'Beautiful Girls'},
#  {'count': 2, 'year': 1992, 'title': 'Unforgiven'},
#  {'count': 2, 'year': 2001, 'title': 'Chaos'},
#  {'count': 2, 'year': 1995, 'title': 'Dead Presidents'},
#  {'count': 2, 'year': 1994, 'title': 'What Happened Was...'},
#  {'count': 2, 'year': 1997, 'title': 'The Truce'},
#  {'count': 2, 'year': 2007, 'title': 'The Life of Buddha'},
#  {'count': 2, 'year': 2009, 'title': 'Road, Movie'},
#  {'count': 2, 'year': 1987, 'title': 'The Untouchables'},
#  {'count': 2, 'year': 2014, 'title': 'Sabotage'},
#  {'count': 2, 'year': 2010, 'title': 'Raavan'},
#  {'count': 2, 'year': 2009, 'title': 'If I Were You 2'},
#  {'count': 2, 'year': 1998, 'title': 'La vendedora de rosas'},
#  {'count': 2, 'year': 2004, 'title': 'Bionicle 2: Legends of Metru Nui'},
#  {'count': 2, 'year': 2001, 'title': 'Family Secrets'},
#  {'count': 2, 'year': 1988, 'title': 'Stand and Deliver'},
#  {'count': 2, 'year': 2004, 'title': 'Lucky Luke and the Daltons'},
#  {'count': 2, 'year': 2011, 'title': 'Girl Walks Into a Bar'},
#  {'count': 2, 'year': 2007, 'title': 'Om Shanti Om'},
#  {'count': 2, 'year': 1974, 'title': 'The Little Prince'},
#  {'count': 2,
#   'year': 2000,
#   'title': 'Forklift Driver Klaus: The First Day on the Job'},
#  {'count': 2, 'year': 2004, 'title': 'Ab Tak Chhappan'},
#  {'count': 2, 'year': 1972, 'title': 'Frenzy'},
#  {'count': 2, 'year': 2012, 'title': 'Villegas'},
#  {'count': 2, 'year': 2007, 'title': 'Interview'},
#  {'count': 2, 'year': 1975, 'title': 'Xala'},
#  {'count': 2, 'year': 1971, 'title': 'Joe Hill'},
#  {'count': 2, 'year': 2001, 'title': 'Kabhi Khushi Kabhie Gham...'},
#  {'count': 2, 'year': 2008, 'title': 'Sorry for the Disturbance'},
#  {'count': 2, 'year': 1983, 'title': 'Flashdance'},
#  {'count': 2, 'year': 1962, 'title': 'Two for the Seesaw'},
#  {'count': 2, 'year': 1990, 'title': 'La dèsenchantèe'},
#  {'count': 2, 'year': 2002, 'title': 'Love in the Time of Money'},
#  {'count': 2, 'year': 1999, 'title': 'Better Than Chocolate'},
#  {'count': 2, 'year': 2006, 'title': '4 Elements'},
#  {'count': 2, 'year': 1995, 'title': 'Heat'},
#  {'count': 2, 'year': 2015, 'title': 'Bessie'},
#  {'count': 2, 'year': 1973, 'title': 'O Lucky Man!'},
#  {'count': 2, 'year': 1988, 'title': 'Twins'},
#  {'count': 2, 'year': 2005, 'title': 'Wedding Chest'},
#  {'count': 2, 'year': 2013, 'title': 'Firestorm'},
#  {'count': 2, 'year': 2007, 'title': 'Shadows'},
#  {'count': 2, 'year': 2009, 'title': 'Beautiful'},
#  {'count': 2, 'year': 1997, 'title': 'Princess Mononoke'},
#  {'count': 2, 'year': 2004, 'title': 'Noise'},
#  {'count': 2, 'year': 1997, 'title': 'A Life Less Ordinary'},
#  {'count': 2, 'year': 1978, 'title': 'Newsfront'},
#  {'count': 2, 'year': 1988, 'title': 'Waxwork'},
#  {'count': 2, 'year': 2007, 'title': 'Continental, un film sans fusil'},
#  {'count': 2, 'year': 2015, 'title': 'Night Owls'},
#  {'count': 2, 'year': 1992, 'title': 'Mr. Baseball'},
#  {'count': 2, 'year': 1996, 'title': 'Breathing Room'},
#  {'count': 2, 'year': 2003, 'title': 'Detention'},
#  {'count': 2, 'year': 1973, 'title': 'Bang the Drum Slowly'},
#  {'count': 2, 'year': 2003, 'title': 'Latter Days'},
#  {'count': 2, 'year': 2006, 'title': "The Tiger's Tail"},
#  {'count': 2, 'year': 2000, 'title': 'Jungle'},
#  {'count': 2, 'year': 2003, 'title': 'Ghosts of the Abyss'},
#  {'count': 2, 'year': 2005, 'title': '3è kèlter'},
#  {'count': 2, 'year': 2003, 'title': 'Star Runner'},
#  {'count': 2, 'year': 2000, 'title': 'Urbania'},
#  {'count': 2, 'year': 2005, 'title': 'BloodRayne'},
#  {'count': 2, 'year': 2014, 'title': "Winter's Tale"},
#  {'count': 2, 'year': 2012, 'title': 'Smashed'},
#  {'count': 2, 'year': 2002, 'title': 'Shakthi: The Power'},
#  {'count': 2, 'year': 1990, 'title': 'Heaven and Earth'},
#  {'count': 2, 'year': 1994, 'title': 'Swimming with Sharks'},
#  {'count': 2, 'year': 1989, 'title': 'Bangkok Hilton'},
#  {'count': 2, 'year': 2008, 'title': 'Tear This Heart Out'},
#  {'count': 2, 'year': 2013, 'title': "The Butterfly's Dream"},
#  {'count': 2, 'year': 2011, 'title': 'Source Code'},
#  {'count': 2, 'year': 2007, 'title': 'White Noise 2: The Light'},
#  {'count': 2, 'year': 1943, 'title': 'Victory Through Air Power'},
#  {'count': 2, 'year': 2015, 'title': 'Larry Kramer in Love and Anger'},
#  {'count': 2, 'year': 2011, 'title': 'Miss Representation'},
#  {'count': 2, 'year': 1989, 'title': 'Road House'},
#  {'count': 2, 'year': 1987, 'title': 'Rouge'},
#  {'count': 2,
#   'year': 2009,
#   'title': 'Monsters vs Aliens: Mutant Pumpkins from Outer Space'},
#  {'count': 2, 'year': 2010, 'title': 'Four Days Inside Guantanamo'},
#  {'count': 2, 'year': 2001, 'title': 'Transistor Love Story'},
#  {'count': 2, 'year': 1937, 'title': 'Night Must Fall'},
#  {'count': 2, 'year': 2013, 'title': 'Percy Jackson: Sea of Monsters'},
#  {'count': 2, 'year': 2007, 'title': 'Cèo Sem Dono'},
#  {'count': 2, 'year': 1959, 'title': 'Time Stood Still'},
#  {'count': 2, 'year': 1988, 'title': 'Eight Men Out'},
#  {'count': 2, 'year': 2002, 'title': 'Sammy and Me'},
#  {'count': 2, 'year': 1984, 'title': 'Dreamscape'},
#  {'count': 2, 'year': 2013, 'title': 'Locke'},
#  {'count': 2, 'year': 2011, 'title': 'Maledimiele'},
#  {'count': 2, 'year': 1944, 'title': 'National Velvet'},
#  {'count': 2, 'year': 1980, 'title': 'Tell Me a Riddle'},
#  {'count': 2, 'year': 1954, 'title': 'It Should Happen to You'},
#  {'count': 2, 'year': 2009, 'title': 'Boogie'},
#  {'count': 2, 'year': 2011, 'title': 'Stopped on Track'},
#  {'count': 2, 'year': 2008, 'title': 'Dustbin Baby'},
#  {'count': 2, 'year': 1997, 'title': 'One Eight Seven'},
#  {'count': 2, 'year': 2003, 'title': 'Destino'},
#  {'count': 2, 'year': 1998, 'title': 'Happiness'},
#  {'count': 2, 'year': 1994, 'title': 'Disclosure'},
#  {'count': 2, 'year': 2004, 'title': 'Saving Face'},
#  {'count': 2, 'year': 1996, 'title': 'Striptease'},
#  {'count': 2, 'year': 1961, 'title': 'La viaccia'},
#  {'count': 2, 'year': 1990, 'title': "Child's Play 2"},
#  {'count': 2, 'year': 2007, 'title': "A Stranger's Heart"},
#  {'count': 2, 'year': 2014, 'title': 'PK'},
#  {'count': 2, 'year': 2000, 'title': 'Wings of Hope'},
#  {'count': 2,
#   'year': 2004,
#   'title': 'Anacondas: The Hunt for the Blood Orchid'},
#  {'count': 2, 'year': 1998, 'title': 'Le poulpe'},
#  {'count': 2, 'year': 2000, 'title': 'Animal Factory'},
#  {'count': 2, 'year': 2010, 'title': 'Sacrifice'},
#  {'count': 2, 'year': 2003, 'title': 'Mortadelo & Filemon: The Big Adventure'},
#  {'count': 2, 'year': 2009, 'title': 'Nowhere Boy'},
#  {'count': 2, 'year': 1974, 'title': 'Stavisky...'},
#  {'count': 2, 'year': 2013, 'title': 'West'},
#  {'count': 2, 'year': 1988, 'title': 'Talk Radio'},
#  {'count': 2, 'year': 2007, 'title': 'The Kite Runner'},
#  {'count': 2, 'year': 2010, 'title': 'Hatchet II'},
#  {'count': 2, 'year': 2005, 'title': 'Bewitched'},
#  {'count': 2, 'year': 1996, 'title': 'Flirting with Disaster'},
#  {'count': 2, 'year': 1966, 'title': 'Alfie'},
#  {'count': 2, 'year': 2005, 'title': 'Middle Sexes: Redefining He and She'},
#  {'count': 2, 'year': 1997, 'title': 'Spice World'},
#  {'count': 2, 'year': 1993, 'title': 'Cop & è'},
#  {'count': 2, 'year': 2011, 'title': 'The Best Exotic Marigold Hotel'},
#  {'count': 2, 'year': 1968, 'title': 'It Rains in My Village'},
#  {'count': 2, 'year': 2005, 'title': 'An American Girl Adventure'},
#  {'count': 2, 'year': 1985, 'title': 'My Sweet Little Village'},
#  {'count': 2, 'year': 1973, 'title': 'Cannibal Girls'},
#  {'count': 2, 'year': 2005, 'title': 'Crazy for Christmas'},
#  {'count': 2, 'year': 1987, 'title': 'Julia and Julia'},
#  {'count': 2, 'year': 2012, 'title': 'Just Like a Woman'},
#  {'count': 2, 'year': 2006, 'title': 'Priceless'},
#  {'count': 2, 'year': 1989, 'title': 'Life and Nothing But'},
#  {'count': 2, 'year': 2011, 'title': 'PiraMMMida'},
#  {'count': 2, 'year': 2001, 'title': 'Hush!'},
#  {'count': 2, 'year': 2001, 'title': 'Ghost World'},
#  {'count': 2, 'year': 2003, 'title': 'Kopps'},
#  {'count': 2, 'year': 2006, 'title': 'A Sunday in Kigali'},
#  {'count': 2, 'year': 1998, 'title': "That's the Way I Like It"},
#  {'count': 2, 'year': 1989, 'title': 'Balance'},
#  {'count': 2, 'year': 2012, 'title': 'Isdraken'},
#  {'count': 2, 'year': 2015, 'title': 'Kung Fury'},
#  {'count': 2, 'year': 2014, 'title': 'Approaching the Elephant'},
#  {'count': 2, 'year': 1964, 'title': "A Hard Day's Night"},
#  {'count': 2, 'year': 2009, 'title': 'Phobia 2'},
#  {'count': 2, 'year': 1988, 'title': 'The House on Carroll Street'},
#  {'count': 2, 'year': 1977, 'title': 'Boys'},
#  {'count': 2, 'year': 2012, 'title': 'The Russian Novel'},
#  {'count': 2, 'year': 2014, 'title': 'The Falling'},
#  {'count': 2, 'year': 2008, 'title': 'Female Agents'},
#  {'count': 2, 'year': 2008, 'title': 'Snakes and Earrings'},
#  {'count': 2, 'year': 2010, 'title': 'StarStruck'},
#  {'count': 2, 'year': 2004, 'title': 'Bridget Jones: The Edge of Reason'},
#  {'count': 2, 'year': 2001, 'title': 'Jesus Christ Vampire Hunter'},
#  ...]

# %% [markdown]
# #### Задача 2.2 — **1 балл**

# %% [markdown]
# Используя данные, полученные в задаче 2.1, выведите на экран столбчатую диаграмму, показывающую топ-20 наиболее комментируемых фильмов. По оси ординат выведите названия этих фильмов (подписи разместите слева диаграммы), по оси абсцисс — количество комментариев.
#
# Для решения задачи можно использовать любую библиотеку, например Seaborn или Matplotlib.

# %%
# Ваш код здесь

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Сортируем фильмы по количеству комментариев и берем топ-20
top_movies = sorted(movie_comments, key=lambda x: x["count"], reverse=True)[:20]

# Создаем датафрейм для построения графика

df = pd.DataFrame(top_movies)
# Создаем график
plt.figure(figsize=(10, 8))
sns.barplot(x="count", y="title", data=df)
plt.xlabel("Количество комментариев")
plt.ylabel("Название фильма")
plt.title("Топ-20 наиболее комментируемых фильмов")
plt.show()
